# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from backtester import BackTester
from GavinB import *

# %load_ext autoreload
# %autoreload 2

# %%
bt = BackTester("prices_train.txt")
NUM_TEST_DAYS = 200

# %%
bt.set_getPos(EmaSmaCrossStrategy)
_, _, stats, _, _, _ = bt.backtest(400)

# %%
bt.set_getPos(EmaSmaCrossStrategy)
param_ranges_mr = {
    "ema_period": [5, 10, 15, 20, 30],
    "sma_period": [10, 20, 30, 50, 70],
    "capital_allocation": [4000, 7000],
}
print("Gridsearch: Mean Reversion Strategy")
bt.gridsearch(param_ranges_mr, numTestDays=NUM_TEST_DAYS)
# Out:
# Gridsearch: Mean Reversion Strategy
#
# Testing parameters: {'ema_period': 5, 'sma_period': 10, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-0.29611241768760027),
#  'meanPL': np.float64(-5.7631987437189265),
#  'return': np.float64(-0.00022961266119252737),
#  'score': np.float64(-36.47509625274789),
#  'stdDev': np.float64(307.1189750902896),
#  'totalVolume': np.float64(27007810.470000017)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 10, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-0.2931191908425653),
#  'meanPL': np.float64(-10.01648108040234),
#  'return': np.float64(-0.000229045872922343),
#  'score': np.float64(-63.93905264194858),
#  'stdDev': np.float64(539.2257156154624),
#  'totalVolume': np.float64(47377244.76999999)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 20, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.060274754665046205),
#  'meanPL': np.float64(1.0500091457293848),
#  'return': np.float64(-0.00042875196071263895),
#  'score': np.float64(-26.438887224256728),
#  'stdDev': np.float64(274.8889636998611),
#  'totalVolume': np.float64(16168865.999999985)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 20, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.058469569842933146),
#  'meanPL': np.float64(1.7870468592970872),
#  'return': np.float64(-0.0004303341244688516),
#  'score': np.float64(-46.44167086788909),
#  'stdDev': np.float64(482.2871772718617),
#  'totalVolume': np.float64(28358647.40000003)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 30, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-0.2132255561051055),
#  'meanPL': np.float64(-3.8522655276379307),
#  'return': np.float64(-0.00015755379227092972),
#  'score': np.float64(-32.360914214052535),
#  'stdDev': np.float64(285.086486864146),
#  'totalVolume': np.float64(12453255.149999991)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 30, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-0.21308604226337727),
#  'meanPL': np.float64(-6.755014346733931),
#  'return': np.float64(-0.00015912127745713035),
#  'score': np.float64(-56.778153981560514),
#  'stdDev': np.float64(500.23139634826583),
#  'totalVolume': np.float64(21842929.779999997)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 50, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.266245338378445),
#  'meanPL': np.float64(4.8879024623115335),
#  'return': np.float64(1.648353525745389e-05),
#  'score': np.float64(-24.08154367012675),
#  'stdDev': np.float64(289.6944613243828),
#  'totalVolume': np.float64(8955600.099999996)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 50, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.2661946964946365),
#  'meanPL': np.float64(8.57518565326653),
#  'return': np.float64(1.403569046814751e-05),
#  'score': np.float64(-42.25758787767369),
#  'stdDev': np.float64(508.3277353094022),
#  'totalVolume': np.float64(15704746.090000005)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 70, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.42802703448871987),
#  'meanPL': np.float64(7.973811155779031),
#  'return': np.float64(-0.0005698944991492967),
#  'score': np.float64(-21.422607195094702),
#  'stdDev': np.float64(293.96418350873734),
#  'totalVolume': np.float64(7564686.870000001)}
#
# Testing parameters: {'ema_period': 5, 'sma_period': 70, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.4260841452433422),
#  'meanPL': np.float64(13.927528567839069),
#  'return': np.float64(-0.0005714411361151102),
#  'score': np.float64(-37.65211744244734),
#  'stdDev': np.float64(515.7964601028641),
#  'totalVolume': np.float64(13265466.53000001)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 10, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-1.1552727340262745),
#  'meanPL': np.float64(-22.716068693468),
#  'return': np.float64(-0.00042750133867993577),
#  'score': np.float64(-53.74367864845623),
#  'stdDev': np.float64(310.2760995498823),
#  'totalVolume': np.float64(31681826.370000016)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 10, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-1.1516269829709238),
#  'meanPL': np.float64(-39.73445600502549),
#  'return': np.float64(-0.00042725515811630534),
#  'score': np.float64(-94.17909382880056),
#  'stdDev': np.float64(544.4463782377507),
#  'totalVolume': np.float64(55577273.86999996)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 20, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-1.030756183810195),
#  'meanPL': np.float64(-17.279994723617918),
#  'return': np.float64(-0.0005310180092442814),
#  'score': np.float64(-43.73374991272807),
#  'stdDev': np.float64(264.53755189110154),
#  'totalVolume': np.float64(14182728.380000008)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 20, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-1.0313007506994716),
#  'meanPL': np.float64(-30.321405000000624),
#  'return': np.float64(-0.000532371243880927),
#  'score': np.float64(-76.71560185979172),
#  'stdDev': np.float64(463.941968597911),
#  'totalVolume': np.float64(24877326.39999999)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 30, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.26103862359604224),
#  'meanPL': np.float64(4.845203165829218),
#  'return': np.float64(0.00022638715311422923),
#  'score': np.float64(-24.443955386594098),
#  'stdDev': np.float64(292.89158552423316),
#  'totalVolume': np.float64(10210546.770000005)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 30, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.2607892704260202),
#  'meanPL': np.float64(8.494488417084874),
#  'return': np.float64(0.0002235664306898973),
#  'score': np.float64(-42.90362550574344),
#  'stdDev': np.float64(513.9811392282832),
#  'totalVolume': np.float64(17906704.139999993)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 50, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.07232661905155244),
#  'meanPL': np.float64(1.3398128140704466),
#  'return': np.float64(3.328728078359545e-05),
#  'score': np.float64(-27.891319341828876),
#  'stdDev': np.float64(292.3113215589932),
#  'totalVolume': np.float64(6938624.139999998)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 50, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.0738542371012357),
#  'meanPL': np.float64(2.4005480653264826),
#  'return': np.float64(3.072971594253075e-05),
#  'score': np.float64(-48.88968391472436),
#  'stdDev': np.float64(512.9023198005084),
#  'totalVolume': np.float64(12168303.010000002)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 70, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.3252824551164852),
#  'meanPL': np.float64(5.907828291457447),
#  'return': np.float64(-0.0009706432912832374),
#  'score': np.float64(-22.75155881467232),
#  'stdDev': np.float64(286.5938710612977),
#  'totalVolume': np.float64(5769698.73)}
#
# Testing parameters: {'ema_period': 10, 'sma_period': 70, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.3258185306350253),
#  'meanPL': np.float64(10.38181836683354),
#  'return': np.float64(-0.0009728171987294665),
#  'score': np.float64(-39.898418998554675),
#  'stdDev': np.float64(502.8023736538821),
#  'totalVolume': np.float64(10116637.070000015)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 10, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-1.1656501487014397),
#  'meanPL': np.float64(-21.401222562813725),
#  'return': np.float64(-0.0007682856653636628),
#  'score': np.float64(-50.372659337946104),
#  'stdDev': np.float64(289.7143677513238),
#  'totalVolume': np.float64(18299486.82999998)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 10, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-1.1699778367865918),
#  'meanPL': np.float64(-37.67681304020107),
#  'return': np.float64(-0.000769187146493328),
#  'score': np.float64(-88.49231252638037),
#  'stdDev': np.float64(508.15499486179294),
#  'totalVolume': np.float64(32099006.63000001)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 20, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-1.3737546618999148),
#  'meanPL': np.float64(-22.715467688442313),
#  'return': np.float64(-0.0007242962199759718),
#  'score': np.float64(-48.80775651350291),
#  'stdDev': np.float64(260.9228882506059),
#  'totalVolume': np.float64(15286213.920000011)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 20, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-1.3779795981097458),
#  'meanPL': np.float64(-39.95420047738671),
#  'return': np.float64(-0.0007255921958580321),
#  'score': np.float64(-85.70717462232179),
#  'stdDev': np.float64(457.52974144935064),
#  'totalVolume': np.float64(26814269.779999994)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 30, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.1962614098472715),
#  'meanPL': np.float64(3.654264070352022),
#  'return': np.float64(0.0002335066106906788),
#  'score': np.float64(-25.726608332945098),
#  'stdDev': np.float64(293.80872403297116),
#  'totalVolume': np.float64(9702475.610000005)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 30, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.1950287436920503),
#  'meanPL': np.float64(6.372261633165327),
#  'return': np.float64(0.00022964314010522183),
#  'score': np.float64(-45.18557061980729),
#  'stdDev': np.float64(515.5783225297262),
#  'totalVolume': np.float64(17015564.619999997)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 50, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-0.5339065297219342),
#  'meanPL': np.float64(-10.308187688442137),
#  'return': np.float64(-0.0007329879081651387),
#  'score': np.float64(-40.77428035097139),
#  'stdDev': np.float64(304.66092662529246),
#  'totalVolume': np.float64(6305134.079999999)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 50, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-0.5342255954984991),
#  'meanPL': np.float64(-18.09955123115576),
#  'return': np.float64(-0.000737295658521048),
#  'score': np.float64(-71.56125419382528),
#  'stdDev': np.float64(534.6170296266952),
#  'totalVolume': np.float64(11057766.570000006)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 70, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-0.05408489847101267),
#  'meanPL': np.float64(-0.9955645226129866),
#  'return': np.float64(-0.0016079838453964155),
#  'score': np.float64(-30.042014880410157),
#  'stdDev': np.float64(290.4645035779717),
#  'totalVolume': np.float64(5214164.470000005)}
#
# Testing parameters: {'ema_period': 15, 'sma_period': 70, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-0.0559270432690502),
#  'meanPL': np.float64(-1.8062120351759263),
#  'return': np.float64(-0.00161133911140953),
#  'score': np.float64(-52.76822165378296),
#  'stdDev': np.float64(509.6200961860703),
#  'totalVolume': np.float64(9142142.030000005)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 10, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-1.3193914822804003),
#  'meanPL': np.float64(-24.352547889447504),
#  'return': np.float64(-0.0008975500588480476),
#  'score': np.float64(-53.47784763065137),
#  'stdDev': np.float64(291.2529974120386),
#  'totalVolume': np.float64(12858380.689999988)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 10, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-1.320386608852312),
#  'meanPL': np.float64(-42.77143243718642),
#  'return': np.float64(-0.0008972037665527025),
#  'score': np.float64(-93.88690234626043),
#  'stdDev': np.float64(511.15469909074005),
#  'totalVolume': np.float64(22548628.07000002)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 20, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-1.1555031508826017),
#  'meanPL': np.float64(-19.32978592964803),
#  'return': np.float64(-0.0004850196012378111),
#  'score': np.float64(-45.72684740745815),
#  'stdDev': np.float64(263.9706147781012),
#  'totalVolume': np.float64(16075673.539999992)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 20, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-1.1611957400025112),
#  'meanPL': np.float64(-34.072363542712665),
#  'return': np.float64(-0.0004856182402914752),
#  'score': np.float64(-80.3740170379662),
#  'stdDev': np.float64(463.0165349525353),
#  'totalVolume': np.float64(28201694.93999997)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 30, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.24515215565672782),
#  'meanPL': np.float64(4.597316381909524),
#  'return': np.float64(0.00023532743241438763),
#  'score': np.float64(-24.99427692125633),
#  'stdDev': np.float64(295.9159330316585),
#  'totalVolume': np.float64(9879693.970000003)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 30, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.2433446098319307),
#  'meanPL': np.float64(8.008040025125048),
#  'return': np.float64(0.00023131896485201106),
#  'score': np.float64(-43.92026865953253),
#  'stdDev': np.float64(519.2830868465758),
#  'totalVolume': np.float64(17326488.999999993)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 50, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-0.05786499719943029),
#  'meanPL': np.float64(-1.1256757788945853),
#  'return': np.float64(-0.0005613798842810334),
#  'score': np.float64(-31.82275525457069),
#  'stdDev': np.float64(306.97079475676105),
#  'totalVolume': np.float64(6085381.3)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 50, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-0.05954736886905984),
#  'meanPL': np.float64(-2.032729472362487),
#  'return': np.float64(-0.0005664306001348627),
#  'score': np.float64(-55.89897184016839),
#  'stdDev': np.float64(538.662423678059),
#  'totalVolume': np.float64(10672491.270000001)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 70, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.1353406101852805),
#  'meanPL': np.float64(2.4471472864321946),
#  'return': np.float64(-0.0018140066174807822),
#  'score': np.float64(-26.08481572863432),
#  'stdDev': np.float64(285.31963015066515),
#  'totalVolume': np.float64(4693378.189999997)}
#
# Testing parameters: {'ema_period': 20, 'sma_period': 70, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.135027916554791),
#  'meanPL': np.float64(4.282865854271149),
#  'return': np.float64(-0.0018159885029238626),
#  'score': np.float64(-45.76788288633374),
#  'stdDev': np.float64(500.5074874060488),
#  'totalVolume': np.float64(8228293.770000002)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 10, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-1.0685910117221518),
#  'meanPL': np.float64(-20.13052381909521),
#  'return': np.float64(-0.001301458290712226),
#  'score': np.float64(-49.856986460223425),
#  'stdDev': np.float64(297.2646264112821),
#  'totalVolume': np.float64(9585090.19)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 10, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-1.0692922310386654),
#  'meanPL': np.float64(-35.35063525125624),
#  'return': np.float64(-0.0013005170645596536),
#  'score': np.float64(-87.51819048817222),
#  'stdDev': np.float64(521.6755523691598),
#  'totalVolume': np.float64(16804663.629999995)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 20, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.0327353737608959),
#  'meanPL': np.float64(0.5699376381909823),
#  'return': np.float64(0.00010037277316141498),
#  'score': np.float64(-26.903291476697316),
#  'stdDev': np.float64(274.73229114888295),
#  'totalVolume': np.float64(9509225.359999996)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 20, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.03433548448844081),
#  'meanPL': np.float64(1.0484174623115219),
#  'return': np.float64(0.00010476365470716451),
#  'score': np.float64(-47.13423891470602),
#  'stdDev': np.float64(481.82656377017537),
#  'totalVolume': np.float64(16680086.380000005)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 30, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-0.45372253658306533),
#  'meanPL': np.float64(-7.835855276381916),
#  'return': np.float64(-3.687452265511284e-05),
#  'score': np.float64(-35.08768887187359),
#  'stdDev': np.float64(272.5183359549167),
#  'totalVolume': np.float64(10988058.850000009)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 30, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-0.45964582899114137),
#  'meanPL': np.float64(-13.924535552763901),
#  'return': np.float64(-3.7840113737551424e-05),
#  'score': np.float64(-61.72774641262917),
#  'stdDev': np.float64(478.0321085986527),
#  'totalVolume': np.float64(19269456.880000003)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 50, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(-0.1854572551165886),
#  'meanPL': np.float64(-3.5851845728642746),
#  'return': np.float64(-0.0006192863528165114),
#  'score': np.float64(-34.089927180291646),
#  'stdDev': np.float64(305.04742607427374),
#  'totalVolume': np.float64(5989955.960000004)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 50, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(-0.18630209158679342),
#  'meanPL': np.float64(-6.3209148492461695),
#  'return': np.float64(-0.0006233473828456099),
#  'score': np.float64(-59.85888271885278),
#  'stdDev': np.float64(535.3796786960661),
#  'totalVolume': np.float64(10506749.070000006)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 70, 'capital_allocation': 4000}
# Statistics:
# {'annualSharpe': np.float64(0.05290430264664555),
#  'meanPL': np.float64(0.9468749748742737),
#  'return': np.float64(-0.0021779943604781867),
#  'score': np.float64(-27.295506710469976),
#  'stdDev': np.float64(282.4238168534425),
#  'totalVolume': np.float64(4400461.750000002)}
#
# Testing parameters: {'ema_period': 30, 'sma_period': 70, 'capital_allocation': 7000}
# Statistics:
# {'annualSharpe': np.float64(0.051053784894624324),
#  'meanPL': np.float64(1.6030335929651698),
#  'return': np.float64(-0.0021820888692372724),
#  'score': np.float64(-47.943622904038364),
#  'stdDev': np.float64(495.4665649700353),
#  'totalVolume': np.float64(7715133.389999999)}
#
# ==================================================
# GRID SEARCH COMPLETE
# ==================================================
# Best parameters: {'ema_period': 5, 'sma_period': 70, 'capital_allocation': 4000}
# Best statistics:
# {'annualSharpe': np.float64(0.42802703448871987),
#  'meanPL': np.float64(7.973811155779031),
#  'return': np.float64(-0.0005698944991492967),
#  'score': np.float64(-21.422607195094702),
#  'stdDev': np.float64(293.96418350873734),
#  'totalVolume': np.float64(7564686.870000001)}
# ({'ema_period': 5, 'sma_period': 70, 'capital_allocation': 4000},
#  {'meanPL': np.float64(7.973811155779031),
#   'return': np.float64(-0.0005698944991492967),
#   'stdDev': np.float64(293.96418350873734),
#   'annualSharpe': np.float64(0.42802703448871987),
#   'totalVolume': np.float64(7564686.870000001),
#   'score': np.float64(-21.422607195094702)})

# %%
# 3. Mean Reversion Strategy
bt.set_getPos(MeanReversionStrategy2)
param_ranges_mr = {
    "lookback_period": [14, 20, 24, 29],
    "standard_deviations": [1.8, 2.0, 2.3],
    "max_look_back": [40, 70, 100, 110, 130],
    # "capital_allocation": [4000, 5000, 7000],
}
print("Gridsearch: Mean Reverion Strategy")
bt.gridsearch(param_ranges_mr, numTestDays=NUM_TEST_DAYS)
# Out:
# Gridsearch: Mean Reverion Strategy
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 1.8, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.35375669496213036),
#  'meanPL': np.float64(-4.919660301507481),
#  'return': np.float64(-0.0005640357761460018),
#  'score': np.float64(-26.86438424228434),
#  'stdDev': np.float64(219.4472394077686),
#  'totalVolume': np.float64(13579908.8)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 1.8, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.35375669496214623),
#  'meanPL': np.float64(-4.9196603015077),
#  'return': np.float64(-0.00042061143673003505),
#  'score': np.float64(-26.864384242284554),
#  'stdDev': np.float64(219.44723940776854),
#  'totalVolume': np.float64(12928814.399999995)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 1.8, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.35375669496214107),
#  'meanPL': np.float64(-4.919660301507627),
#  'return': np.float64(-0.0004722039276831173),
#  'score': np.float64(-26.864384242284476),
#  'stdDev': np.float64(219.44723940776848),
#  'totalVolume': np.float64(12231943.99999999)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 1.8, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.35375669496214107),
#  'meanPL': np.float64(-4.919660301507627),
#  'return': np.float64(-0.000495125367533929),
#  'score': np.float64(-26.864384242284476),
#  'stdDev': np.float64(219.44723940776848),
#  'totalVolume': np.float64(11980390.39999999)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 1.8, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.35375669496214623),
#  'meanPL': np.float64(-4.9196603015077),
#  'return': np.float64(-0.00048093012186414726),
#  'score': np.float64(-26.864384242284554),
#  'stdDev': np.float64(219.44723940776854),
#  'totalVolume': np.float64(11536518.399999987)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.0, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(0.032497358633137366),
#  'meanPL': np.float64(0.4482512562815407),
#  'return': np.float64(-0.000515351948210204),
#  'score': np.float64(-21.31747314165744),
#  'stdDev': np.float64(217.6572439793898),
#  'totalVolume': np.float64(12506556.00000001)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.0, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(0.032497358633137366),
#  'meanPL': np.float64(0.4482512562815407),
#  'return': np.float64(-0.00037283085066923226),
#  'score': np.float64(-21.31747314165744),
#  'stdDev': np.float64(217.65724397938982),
#  'totalVolume': np.float64(11864512.800000003)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.0, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(0.032497358633137366),
#  'meanPL': np.float64(0.4482512562815407),
#  'return': np.float64(-0.0004108954699242672),
#  'score': np.float64(-21.31747314165744),
#  'stdDev': np.float64(217.65724397938982),
#  'totalVolume': np.float64(11240730.399999997)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.0, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(0.03249735863313737),
#  'meanPL': np.float64(0.4482512562815407),
#  'return': np.float64(-0.00043327335688730684),
#  'score': np.float64(-21.317473141657437),
#  'stdDev': np.float64(217.65724397938976),
#  'totalVolume': np.float64(11006098.399999995)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.0, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(0.03249735863313208),
#  'meanPL': np.float64(0.44825125628146756),
#  'return': np.float64(-0.000400438192360939),
#  'score': np.float64(-21.3174731416575),
#  'stdDev': np.float64(217.65724397938968),
#  'totalVolume': np.float64(10630582.4)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.3, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.04669366315926006),
#  'meanPL': np.float64(-0.6111979899496096),
#  'return': np.float64(-0.0006790573367279012),
#  'score': np.float64(-21.26612405746922),
#  'stdDev': np.float64(206.54926067519608),
#  'totalVolume': np.float64(10651336.800000008)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.3, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.04669366315925726),
#  'meanPL': np.float64(-0.6111979899495731),
#  'return': np.float64(-0.000503943932114506),
#  'score': np.float64(-21.266124057469185),
#  'stdDev': np.float64(206.54926067519608),
#  'totalVolume': np.float64(10142162.400000006)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.3, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.04669366315926005),
#  'meanPL': np.float64(-0.6111979899496096),
#  'return': np.float64(-0.0005722630394686401),
#  'score': np.float64(-21.26612405746922),
#  'stdDev': np.float64(206.5492606751961),
#  'totalVolume': np.float64(9576126.400000002)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.3, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.04669366315926006),
#  'meanPL': np.float64(-0.6111979899496096),
#  'return': np.float64(-0.0006505139692459971),
#  'score': np.float64(-21.26612405746922),
#  'stdDev': np.float64(206.54926067519608),
#  'totalVolume': np.float64(9343983.200000003)}
#
# Testing parameters: {'lookback_period': 14, 'standard_deviations': 2.3, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.04669366315926005),
#  'meanPL': np.float64(-0.6111979899496096),
#  'return': np.float64(-0.0005873407238703456),
#  'score': np.float64(-21.26612405746922),
#  'stdDev': np.float64(206.5492606751961),
#  'totalVolume': np.float64(9031296.799999999)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 1.8, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.08060755744039712),
#  'meanPL': np.float64(-1.184741708542742),
#  'return': np.float64(-0.0006592174746570261),
#  'score': np.float64(-24.377243033838116),
#  'stdDev': np.float64(231.92501325295373),
#  'totalVolume': np.float64(10089344.80000001)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 1.8, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.0806075574403872),
#  'meanPL': np.float64(-1.184741708542596),
#  'return': np.float64(-0.0006366031960275122),
#  'score': np.float64(-24.377243033837967),
#  'stdDev': np.float64(231.9250132529537),
#  'totalVolume': np.float64(9522471.200000009)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 1.8, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.0806075574403872),
#  'meanPL': np.float64(-1.184741708542596),
#  'return': np.float64(-0.0006554335756339554),
#  'score': np.float64(-24.377243033837967),
#  'stdDev': np.float64(231.9250132529537),
#  'totalVolume': np.float64(9043091.200000005)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 1.8, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.0806075574403971),
#  'meanPL': np.float64(-1.184741708542742),
#  'return': np.float64(-0.0006506339488159757),
#  'score': np.float64(-24.37724303383812),
#  'stdDev': np.float64(231.92501325295376),
#  'totalVolume': np.float64(8832006.400000002)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 1.8, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.08060755744039466),
#  'meanPL': np.float64(-1.1847417085427057),
#  'return': np.float64(-0.0005594276712831802),
#  'score': np.float64(-24.377243033838077),
#  'stdDev': np.float64(231.9250132529537),
#  'totalVolume': np.float64(8548206.399999997)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.0, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.40307648156350206),
#  'meanPL': np.float64(-5.749212060301779),
#  'return': np.float64(-0.0007664188760234024),
#  'score': np.float64(-28.25636398795183),
#  'stdDev': np.float64(225.07151927650048),
#  'totalVolume': np.float64(9104460.000000006)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.0, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.40307648156350184),
#  'meanPL': np.float64(-5.749212060301779),
#  'return': np.float64(-0.0007073645549486917),
#  'score': np.float64(-28.25636398795184),
#  'stdDev': np.float64(225.0715192765006),
#  'totalVolume': np.float64(8634069.600000003)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.0, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.40307648156350184),
#  'meanPL': np.float64(-5.749212060301779),
#  'return': np.float64(-0.0007103795676386528),
#  'score': np.float64(-28.25636398795184),
#  'stdDev': np.float64(225.0715192765006),
#  'totalVolume': np.float64(8168093.600000002)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.0, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.40307648156350184),
#  'meanPL': np.float64(-5.749212060301779),
#  'return': np.float64(-0.0007282674073653982),
#  'score': np.float64(-28.25636398795184),
#  'stdDev': np.float64(225.0715192765006),
#  'totalVolume': np.float64(7997637.600000003)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.0, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.40307648156350184),
#  'meanPL': np.float64(-5.749212060301779),
#  'return': np.float64(-0.0006652536172496739),
#  'score': np.float64(-28.25636398795184),
#  'stdDev': np.float64(225.0715192765006),
#  'totalVolume': np.float64(7735988.000000005)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.3, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.004896698378118633),
#  'meanPL': np.float64(-0.06395376884435092),
#  'return': np.float64(-0.0009387377566357797),
#  'score': np.float64(-20.673216835040705),
#  'stdDev': np.float64(206.09263066196354),
#  'totalVolume': np.float64(7749503.999999999)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.3, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.004896698378115834),
#  'meanPL': np.float64(-0.06395376884431435),
#  'return': np.float64(-0.0008641934071009413),
#  'score': np.float64(-20.67321683504067),
#  'stdDev': np.float64(206.09263066196354),
#  'totalVolume': np.float64(7371907.2)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.3, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.0048966983781158335),
#  'meanPL': np.float64(-0.06395376884431435),
#  'return': np.float64(-0.0008365214229812912),
#  'score': np.float64(-20.673216835040677),
#  'stdDev': np.float64(206.0926306619636),
#  'totalVolume': np.float64(6979644.800000002)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.3, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.004896698378115834),
#  'meanPL': np.float64(-0.06395376884431435),
#  'return': np.float64(-0.0009373335632485245),
#  'score': np.float64(-20.67321683504067),
#  'stdDev': np.float64(206.09263066196354),
#  'totalVolume': np.float64(6792069.600000001)}
#
# Testing parameters: {'lookback_period': 20, 'standard_deviations': 2.3, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.0048966983781158335),
#  'meanPL': np.float64(-0.06395376884431435),
#  'return': np.float64(-0.0008540613620927302),
#  'score': np.float64(-20.673216835040677),
#  'stdDev': np.float64(206.0926306619636),
#  'totalVolume': np.float64(6554796.000000003)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 1.8, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.4619520569046483),
#  'meanPL': np.float64(-6.991111557788991),
#  'return': np.float64(-0.000880935757918552),
#  'score': np.float64(-30.871918659999288),
#  'stdDev': np.float64(238.80807102210298),
#  'totalVolume': np.float64(8690179.200000001)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 1.8, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.4619520569046484),
#  'meanPL': np.float64(-6.991111557788991),
#  'return': np.float64(-0.0007443285193730688),
#  'score': np.float64(-30.871918659999285),
#  'stdDev': np.float64(238.80807102210292),
#  'totalVolume': np.float64(8211894.400000002)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 1.8, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.4619520569046484),
#  'meanPL': np.float64(-6.991111557788991),
#  'return': np.float64(-0.0007836179535612881),
#  'score': np.float64(-30.871918659999285),
#  'stdDev': np.float64(238.80807102210292),
#  'totalVolume': np.float64(7782300.000000001)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 1.8, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.4619520569046556),
#  'meanPL': np.float64(-6.991111557789101),
#  'return': np.float64(-0.0007375287671100454),
#  'score': np.float64(-30.871918659999398),
#  'stdDev': np.float64(238.80807102210298),
#  'totalVolume': np.float64(7608341.6)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 1.8, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.4619520569046559),
#  'meanPL': np.float64(-6.991111557789101),
#  'return': np.float64(-0.0007368347698762809),
#  'score': np.float64(-30.871918659999384),
#  'stdDev': np.float64(238.8080710221028),
#  'totalVolume': np.float64(7330004.799999999)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.0, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.7014636853626826),
#  'meanPL': np.float64(-10.050462311557942),
#  'return': np.float64(-0.0008578434372846884),
#  'score': np.float64(-32.659418916892946),
#  'stdDev': np.float64(226.08956605335),
#  'totalVolume': np.float64(7920782.400000001)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.0, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.7014636853626876),
#  'meanPL': np.float64(-10.050462311558015),
#  'return': np.float64(-0.000823432427979329),
#  'score': np.float64(-32.65941891689302),
#  'stdDev': np.float64(226.08956605335),
#  'totalVolume': np.float64(7477296.000000002)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.0, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.7014636853626874),
#  'meanPL': np.float64(-10.050462311558015),
#  'return': np.float64(-0.000834090975664417),
#  'score': np.float64(-32.659418916893024),
#  'stdDev': np.float64(226.08956605335007),
#  'totalVolume': np.float64(7073522.3999999985)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.0, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.70146368536269),
#  'meanPL': np.float64(-10.050462311558052),
#  'return': np.float64(-0.0008214373392524532),
#  'score': np.float64(-32.65941891689306),
#  'stdDev': np.float64(226.0895660533501),
#  'totalVolume': np.float64(6921411.199999998)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.0, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.70146368536269),
#  'meanPL': np.float64(-10.050462311558052),
#  'return': np.float64(-0.0008007930457320979),
#  'score': np.float64(-32.65941891689306),
#  'stdDev': np.float64(226.0895660533501),
#  'totalVolume': np.float64(6657068.8)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.3, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-1.1259329284832378),
#  'meanPL': np.float64(-14.646104522613113),
#  'return': np.float64(-0.0013869757191162736),
#  'score': np.float64(-35.17233883770403),
#  'stdDev': np.float64(205.26234315090917),
#  'totalVolume': np.float64(6529152.8)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.3, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-1.1259329284832404),
#  'meanPL': np.float64(-14.646104522613149),
#  'return': np.float64(-0.001236367892499599),
#  'score': np.float64(-35.17233883770407),
#  'stdDev': np.float64(205.26234315090917),
#  'totalVolume': np.float64(6192556.800000001)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.3, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-1.1259329284832464),
#  'meanPL': np.float64(-14.646104522613223),
#  'return': np.float64(-0.0012358055766589265),
#  'score': np.float64(-35.17233883770414),
#  'stdDev': np.float64(205.26234315090912),
#  'totalVolume': np.float64(5887424.800000004)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.3, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-1.1259329284832404),
#  'meanPL': np.float64(-14.646104522613149),
#  'return': np.float64(-0.001385293777162114),
#  'score': np.float64(-35.17233883770407),
#  'stdDev': np.float64(205.26234315090917),
#  'totalVolume': np.float64(5721942.400000003)}
#
# Testing parameters: {'lookback_period': 24, 'standard_deviations': 2.3, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-1.1259329284832464),
#  'meanPL': np.float64(-14.646104522613223),
#  'return': np.float64(-0.0013515873946467652),
#  'score': np.float64(-35.17233883770414),
#  'stdDev': np.float64(205.26234315090912),
#  'totalVolume': np.float64(5505952.8000000045)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 1.8, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.3858197990860425),
#  'meanPL': np.float64(-5.864068341708652),
#  'return': np.float64(-0.0006441872441152445),
#  'score': np.float64(-29.847658053681258),
#  'stdDev': np.float64(239.83589711972604),
#  'totalVolume': np.float64(7562388.799999994)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 1.8, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.38581979908604264),
#  'meanPL': np.float64(-5.864068341708652),
#  'return': np.float64(-0.0006467853776980391),
#  'score': np.float64(-29.84765805368125),
#  'stdDev': np.float64(239.83589711972598),
#  'totalVolume': np.float64(7101524.799999992)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 1.8, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.38581979908604264),
#  'meanPL': np.float64(-5.864068341708652),
#  'return': np.float64(-0.0005239457556678919),
#  'score': np.float64(-29.84765805368125),
#  'stdDev': np.float64(239.83589711972598),
#  'totalVolume': np.float64(6781995.199999992)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 1.8, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.38581979908604264),
#  'meanPL': np.float64(-5.864068341708652),
#  'return': np.float64(-0.0005430680466668939),
#  'score': np.float64(-29.84765805368125),
#  'stdDev': np.float64(239.83589711972598),
#  'totalVolume': np.float64(6612791.199999992)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 1.8, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.38581979908604264),
#  'meanPL': np.float64(-5.864068341708652),
#  'return': np.float64(-0.0005377038670639323),
#  'score': np.float64(-29.84765805368125),
#  'stdDev': np.float64(239.83589711972598),
#  'totalVolume': np.float64(6386612.799999991)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.0, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.5980458498287576),
#  'meanPL': np.float64(-8.777236180905026),
#  'return': np.float64(-0.000568678371606674),
#  'score': np.float64(-31.936405466692314),
#  'stdDev': np.float64(231.59169285787286),
#  'totalVolume': np.float64(6860966.399999995)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.0, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.5980458498287551),
#  'meanPL': np.float64(-8.777236180904989),
#  'return': np.float64(-0.000506066212336263),
#  'score': np.float64(-31.936405466692275),
#  'stdDev': np.float64(231.59169285787283),
#  'totalVolume': np.float64(6462022.399999995)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.0, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.5980458498287575),
#  'meanPL': np.float64(-8.777236180905026),
#  'return': np.float64(-0.0003595425578910052),
#  'score': np.float64(-31.936405466692314),
#  'stdDev': np.float64(231.59169285787289),
#  'totalVolume': np.float64(6162720.799999997)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.0, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.5980458498287524),
#  'meanPL': np.float64(-8.777236180904952),
#  'return': np.float64(-0.0003069032422231323),
#  'score': np.float64(-31.936405466692243),
#  'stdDev': np.float64(231.59169285787289),
#  'totalVolume': np.float64(6036351.999999997)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.0, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.5980458498287524),
#  'meanPL': np.float64(-8.777236180904952),
#  'return': np.float64(-0.0003367483236789893),
#  'score': np.float64(-31.936405466692243),
#  'stdDev': np.float64(231.59169285787289),
#  'totalVolume': np.float64(5816785.599999997)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.3, 'max_look_back': 40}
# Statistics:
# {'annualSharpe': np.float64(-0.9514877840468825),
#  'meanPL': np.float64(-12.85766834170876),
#  'return': np.float64(-0.0006716165416668325),
#  'score': np.float64(-34.18117744103432),
#  'stdDev': np.float64(213.23509099325557),
#  'totalVolume': np.float64(5757020.8)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.3, 'max_look_back': 70}
# Statistics:
# {'annualSharpe': np.float64(-0.9514877840468827),
#  'meanPL': np.float64(-12.85766834170876),
#  'return': np.float64(-0.0005952267622339919),
#  'score': np.float64(-34.18117744103431),
#  'stdDev': np.float64(213.2350909932555),
#  'totalVolume': np.float64(5418644.799999998)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.3, 'max_look_back': 100}
# Statistics:
# {'annualSharpe': np.float64(-0.9514877840468827),
#  'meanPL': np.float64(-12.85766834170876),
#  'return': np.float64(-0.00037739033019431434),
#  'score': np.float64(-34.18117744103431),
#  'stdDev': np.float64(213.2350909932555),
#  'totalVolume': np.float64(5193717.599999997)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.3, 'max_look_back': 110}
# Statistics:
# {'annualSharpe': np.float64(-0.9514877840468827),
#  'meanPL': np.float64(-12.85766834170876),
#  'return': np.float64(-0.00045351182578510417),
#  'score': np.float64(-34.18117744103431),
#  'stdDev': np.float64(213.2350909932555),
#  'totalVolume': np.float64(5059351.199999996)}
#
# Testing parameters: {'lookback_period': 29, 'standard_deviations': 2.3, 'max_look_back': 130}
# Statistics:
# {'annualSharpe': np.float64(-0.9514877840468827),
#  'meanPL': np.float64(-12.85766834170876),
#  'return': np.float64(-0.00047595245965984786),
#  'score': np.float64(-34.18117744103431),
#  'stdDev': np.float64(213.2350909932555),
#  'totalVolume': np.float64(4857045.599999996)}
#
# ==================================================
# GRID SEARCH COMPLETE
# ==================================================
# Best parameters: {'lookback_period': 20, 'standard_deviations': 2.3, 'max_look_back': 70}
# Best statistics:
# {'annualSharpe': np.float64(-0.004896698378115834),
#  'meanPL': np.float64(-0.06395376884431435),
#  'return': np.float64(-0.0008641934071009413),
#  'score': np.float64(-20.67321683504067),
#  'stdDev': np.float64(206.09263066196354),
#  'totalVolume': np.float64(7371907.2)}
# ({'lookback_period': 20, 'standard_deviations': 2.3, 'max_look_back': 70},
#  {'meanPL': np.float64(-0.06395376884431435),
#   'return': np.float64(-0.0008641934071009413),
#   'stdDev': np.float64(206.09263066196354),
#   'annualSharpe': np.float64(-0.004896698378115834),
#   'totalVolume': np.float64(7371907.2),
#   'score': np.float64(-20.67321683504067)})

# %%
# 4. Momentum Strategy
bt.set_getPos(MomentumStrategy)
param_ranges_mom = {
    "momentum_period": [3, 5, 7],
    "momentum_threshold": [0.015, 0.02, 0.025],
    "capital_allocation": [3000, 5000, 8000],
}
print("Gridsearch: Momentum Strategy")
bt.gridsearch(param_ranges_mom, numTestDays=NUM_TEST_DAYS)
# Out:
# Gridsearch: Momentum Strategy
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.9307420708130825),
#  'meanPL': np.float64(35.394777512563316),
#  'return': np.float64(0.001938261357561272),
#  'score': np.float64(-24.613272614328217),
#  'stdDev': np.float64(600.0805012689153),
#  'totalVolume': np.float64(3617848.419999998)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.9158035584929805),
#  'meanPL': np.float64(36.60967464824092),
#  'return': np.float64(0.0018588239599125593),
#  'score': np.float64(-26.470547795732493),
#  'stdDev': np.float64(630.8022244397341),
#  'totalVolume': np.float64(3891227.2200000016)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.8330062006035319),
#  'meanPL': np.float64(34.05027256281452),
#  'return': np.float64(0.0016521028423525754),
#  'score': np.float64(-30.451556807159456),
#  'stdDev': np.float64(645.0182936997397),
#  'totalVolume': np.float64(4050731.1400000006)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.214360371472534),
#  'meanPL': np.float64(43.73360821608024),
#  'return': np.float64(0.0033234835666406926),
#  'score': np.float64(-13.095049375150033),
#  'stdDev': np.float64(568.2865759123027),
#  'totalVolume': np.float64(2611927.010000002)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.3935782402324874),
#  'meanPL': np.float64(53.21755605527666),
#  'return': np.float64(0.003720322175687908),
#  'score': np.float64(-7.041627521253801),
#  'stdDev': np.float64(602.5918357653046),
#  'totalVolume': np.float64(2836579.650000003)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.364534305438044),
#  'meanPL': np.float64(54.172152814069875),
#  'return': np.float64(0.003628705816922547),
#  'score': np.float64(-8.473553448792657),
#  'stdDev': np.float64(626.4570626286253),
#  'totalVolume': np.float64(2954339.8199999994)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.37411222615617185),
#  'meanPL': np.float64(11.750362261306494),
#  'return': np.float64(0.0010971323063553144),
#  'score': np.float64(-37.811661115816044),
#  'stdDev': np.float64(495.62023377122534),
#  'totalVolume': np.float64(2119110.5999999987)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.4180202328117008),
#  'meanPL': np.float64(14.500262738693293),
#  'return': np.float64(0.001186654330616114),
#  'score': np.float64(-40.236390810222495),
#  'stdDev': np.float64(547.3665354891579),
#  'totalVolume': np.float64(2412776.540000001)}
#
# Testing parameters: {'momentum_period': 3, 'momentum_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.36052585009091165),
#  'meanPL': np.float64(13.213375653265839),
#  'return': np.float64(0.0010200485576703985),
#  'score': np.float64(-44.61980076341925),
#  'stdDev': np.float64(578.3317641668508),
#  'totalVolume': np.float64(2542576.6699999995)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.5350214779047064),
#  'meanPL': np.float64(61.4274975879395),
#  'return': np.float64(0.0034101471490510793),
#  'score': np.float64(-1.718821615282863),
#  'stdDev': np.float64(631.4631920322236),
#  'totalVolume': np.float64(3576773.3199999984)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.3134668671165513),
#  'meanPL': np.float64(54.63408095477308),
#  'return': np.float64(0.002796987394446383),
#  'score': np.float64(-11.002234474020668),
#  'stdDev': np.float64(656.3631542879375),
#  'totalVolume': np.float64(3871094.5700000008)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.1461850062668597),
#  'meanPL': np.float64(48.93269763819087),
#  'return': np.float64(0.00237582429857616),
#  'score': np.float64(-18.433821770729104),
#  'stdDev': np.float64(673.6651940891996),
#  'totalVolume': np.float64(4068419.6199999982)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(2.0670039449855633),
#  'meanPL': np.float64(78.56574301507622),
#  'return': np.float64(0.005735547576008915),
#  'score': np.float64(18.587796839654487),
#  'stdDev': np.float64(599.7794617542173),
#  'totalVolume': np.float64(2722800.1700000013)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(2.1795696770142134),
#  'meanPL': np.float64(86.42313253768744),
#  'return': np.float64(0.006133741332662452),
#  'score': np.float64(23.854174854066926),
#  'stdDev': np.float64(625.6895768362051),
#  'totalVolume': np.float64(2798999.6999999993)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(2.220658673006283),
#  'meanPL': np.float64(89.66391301507558),
#  'return': np.float64(0.006325261713988892),
#  'score': np.float64(25.949813254692977),
#  'stdDev': np.float64(637.140997603826),
#  'totalVolume': np.float64(2813363.1799999997)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.9956123579968681),
#  'meanPL': np.float64(35.14150170854222),
#  'return': np.float64(0.0028329312130394285),
#  'score': np.float64(-20.55522997387567),
#  'stdDev': np.float64(556.9673168241789),
#  'totalVolume': np.float64(2463276.1599999988)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.8480460118990005),
#  'meanPL': np.float64(31.847363090452422),
#  'return': np.float64(0.00236187589149273),
#  'score': np.float64(-27.41155752943848),
#  'stdDev': np.float64(592.589206198909),
#  'totalVolume': np.float64(2672764.4)}
#
# Testing parameters: {'momentum_period': 5, 'momentum_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.9016147985167954),
#  'meanPL': np.float64(34.96144344221144),
#  'return': np.float64(0.0025230986906200205),
#  'score': np.float64(-26.22680158438019),
#  'stdDev': np.float64(611.8824502659163),
#  'totalVolume': np.float64(2741647.180000002)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.2476376647743987),
#  'meanPL': np.float64(52.67306479899488),
#  'return': np.float64(0.0032003979491646733),
#  'score': np.float64(-13.946192252153388),
#  'stdDev': np.float64(666.1925705114827),
#  'totalVolume': np.float64(3263097.69)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.2903470405597797),
#  'meanPL': np.float64(55.92006402010039),
#  'return': np.float64(0.0032765112056857017),
#  'score': np.float64(-12.464928443758502),
#  'stdDev': np.float64(683.849924638589),
#  'totalVolume': np.float64(3376560.8800000013)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.3016404336113894),
#  'meanPL': np.float64(56.817771407035224),
#  'return': np.float64(0.0032159640637901103),
#  'score': np.float64(-12.062180914912858),
#  'stdDev': np.float64(688.7995232194808),
#  'totalVolume': np.float64(3483548.2200000007)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.0464154901083675),
#  'meanPL': np.float64(42.88854329145761),
#  'return': np.float64(0.002825560456998311),
#  'score': np.float64(-21.786512098940577),
#  'stdDev': np.float64(646.7505539039819),
#  'totalVolume': np.float64(3012153.9300000016)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.8813247893454903),
#  'meanPL': np.float64(37.2609246231157),
#  'return': np.float64(0.002290654176696038),
#  'score': np.float64(-29.453126793662577),
#  'stdDev': np.float64(667.1405141677827),
#  'totalVolume': np.float64(3219628.600000004)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.6969472467999129),
#  'meanPL': np.float64(29.976802135678017),
#  'return': np.float64(0.0017409630389410686),
#  'score': np.float64(-37.894326014853874),
#  'stdDev': np.float64(678.7112815053189),
#  'totalVolume': np.float64(3389806.019999998)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.1425996398047276),
#  'meanPL': np.float64(43.733249698492656),
#  'return': np.float64(0.003348684670242134),
#  'score': np.float64(-16.664024733831624),
#  'stdDev': np.float64(603.9727443232428),
#  'totalVolume': np.float64(2593135.2799999984)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.0094993910398413),
#  'meanPL': np.float64(40.214678065326126),
#  'return': np.float64(0.0028755925535579314),
#  'score': np.float64(-22.645876570615336),
#  'stdDev': np.float64(628.6055463594146),
#  'totalVolume': np.float64(2771717.8100000005)}
#
# Testing parameters: {'momentum_period': 7, 'momentum_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.9583278054735788),
#  'meanPL': np.float64(39.30216829145697),
#  'return': np.float64(0.0027091010098502103),
#  'score': np.float64(-25.41240550631968),
#  'stdDev': np.float64(647.1457379777665),
#  'totalVolume': np.float64(2867831.1999999993)}
#
# ==================================================
# GRID SEARCH COMPLETE
# ==================================================
# Best parameters: {'momentum_period': 5, 'momentum_threshold': 0.02, 'capital_allocation': 8000}
# Best statistics:
# {'annualSharpe': np.float64(2.220658673006283),
#  'meanPL': np.float64(89.66391301507558),
#  'return': np.float64(0.006325261713988892),
#  'score': np.float64(25.949813254692977),
#  'stdDev': np.float64(637.140997603826),
#  'totalVolume': np.float64(2813363.1799999997)}
# ({'momentum_period': 5,
#   'momentum_threshold': 0.02,
#   'capital_allocation': 8000},
#  {'meanPL': np.float64(89.66391301507558),
#   'return': np.float64(0.006325261713988892),
#   'stdDev': np.float64(637.140997603826),
#   'annualSharpe': np.float64(2.220658673006283),
#   'totalVolume': np.float64(2813363.1799999997),
#   'score': np.float64(25.949813254692977)})

# %%
# Backtest for ROC Momentum Strategy
bt.set_getPos(MomentumROCStrategy)  # Set our adapted strategy

# Define parameter search space
param_ranges_roc = {
    "roc_period": [3, 4, 5, 6, 7],  # ROC calculation window
    "ma_period": [2, 3, 4, 5],  # Moving average window for ROC
    "roc_threshold": [0.01, 0.015, 0.02, 0.025, 0.03],  # Deviation threshold
    "capital_allocation": [3000, 5000, 8000],
}

print("Gridsearch: ROC Momentum Strategy")
bt.gridsearch(param_ranges_roc, numTestDays=NUM_TEST_DAYS)
# Out:
# Gridsearch: ROC Momentum Strategy
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.8623323985427525),
#  'meanPL': np.float64(-24.863977562814142),
#  'return': np.float64(-0.0014263563924111914),
#  'score': np.float64(-70.36232005344931),
#  'stdDev': np.float64(454.9834249063516),
#  'totalVolume': np.float64(3474138.059999999)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-1.154628052870717),
#  'meanPL': np.float64(-41.15588439698509),
#  'return': np.float64(-0.0018506337619128561),
#  'score': np.float64(-97.40160786089324),
#  'stdDev': np.float64(562.4572346390814),
#  'totalVolume': np.float64(4432237.790000004)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.9003708881605205),
#  'meanPL': np.float64(-36.43659575376902),
#  'return': np.float64(-0.0014936428354647958),
#  'score': np.float64(-100.2947002882349),
#  'stdDev': np.float64(638.5810453446588),
#  'totalVolume': np.float64(4867855.759999998)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-2.070065185358649),
#  'meanPL': np.float64(-38.62571879397001),
#  'return': np.float64(-0.006603858519522116),
#  'score': np.float64(-68.06940811271868),
#  'stdDev': np.float64(294.4368931874867),
#  'totalVolume': np.float64(1164168.529999999)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-1.6175226670866052),
#  'meanPL': np.float64(-41.09707517587936),
#  'return': np.float64(-0.004867375531109282),
#  'score': np.float64(-81.18930516398478),
#  'stdDev': np.float64(400.92229988105424),
#  'totalVolume': np.float64(1680741.6599999995)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-1.6555067652336257),
#  'meanPL': np.float64(-50.567804296482386),
#  'return': np.float64(-0.004987062089722346),
#  'score': np.float64(-98.76733505834957),
#  'stdDev': np.float64(481.99530761867175),
#  'totalVolume': np.float64(2018619.2699999998)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.9184747312128443),
#  'meanPL': np.float64(11.380883040200995),
#  'return': np.float64(0.007068903445519507),
#  'score': np.float64(-8.17189278622946),
#  'stdDev': np.float64(195.52775826430454),
#  'totalVolume': np.float64(320388.5499999999)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.1890641887403193),
#  'meanPL': np.float64(22.176372939698528),
#  'return': np.float64(0.008697755457473732),
#  'score': np.float64(-7.2532630543605805),
#  'stdDev': np.float64(294.29635994059106),
#  'totalVolume': np.float64(507383.5700000002)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.4917837262892502),
#  'meanPL': np.float64(36.280234497487406),
#  'return': np.float64(0.010747112122662382),
#  'score': np.float64(-2.0961356065615746),
#  'stdDev': np.float64(383.76370104048976),
#  'totalVolume': np.float64(671786.67)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.7734551282230601),
#  'meanPL': np.float64(-5.460681331658287),
#  'return': np.float64(-0.015204390595536622),
#  'score': np.float64(-16.601353213424865),
#  'stdDev': np.float64(111.40671881766578),
#  'totalVolume': np.float64(71471.17)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.7749545254100986),
#  'meanPL': np.float64(-9.136697638190954),
#  'return': np.float64(-0.015224557519715614),
#  'score': np.float64(-27.740970813211675),
#  'stdDev': np.float64(186.0427317502072),
#  'totalVolume': np.float64(119425.66)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.7195110117234417),
#  'meanPL': np.float64(-13.218886507537713),
#  'return': np.float64(-0.014245659989939199),
#  'score': np.float64(-42.20947974735833),
#  'stdDev': np.float64(289.9059323982062),
#  'totalVolume': np.float64(184656.83000000005)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.716666268520461),
#  'meanPL': np.float64(47.16603173366824),
#  'return': np.float64(0.0014416897752388988),
#  'score': np.float64(3.810637583807484),
#  'stdDev': np.float64(433.55394149860757),
#  'totalVolume': np.float64(6498072.020000002)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.4177618220350416),
#  'meanPL': np.float64(45.15391831658305),
#  'return': np.float64(0.0011266604185518302),
#  'score': np.float64(-5.102535320913013),
#  'stdDev': np.float64(502.56453637496065),
#  'totalVolume': np.float64(7948936.270000003)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.2046774817574009),
#  'meanPL': np.float64(41.00700356783878),
#  'return': np.float64(0.0009341751716195657),
#  'score': np.float64(-12.706924981143743),
#  'stdDev': np.float64(537.1392854898252),
#  'totalVolume': np.float64(8684162.33)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.3975721556482725),
#  'meanPL': np.float64(33.716656557788866),
#  'return': np.float64(0.0018834772872381648),
#  'score': np.float64(-4.352209099053134),
#  'stdDev': np.float64(380.68865656842),
#  'totalVolume': np.float64(3556841.110000001)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.2858655540556279),
#  'meanPL': np.float64(39.708562437185876),
#  'return': np.float64(0.001713139009858101),
#  'score': np.float64(-9.020524703727872),
#  'stdDev': np.float64(487.2908714091375),
#  'totalVolume': np.float64(4602422.1499999985)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.9859054913992026),
#  'meanPL': np.float64(34.09343439698505),
#  'return': np.float64(0.0012923794216549748),
#  'score': np.float64(-20.474201659718005),
#  'stdDev': np.float64(545.6763605670305),
#  'totalVolume': np.float64(5228095.059999996)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.9147137372388194),
#  'meanPL': np.float64(-17.646053793969763),
#  'return': np.float64(-0.0020030783268956682),
#  'score': np.float64(-48.08727500066772),
#  'stdDev': np.float64(304.4122120669795),
#  'totalVolume': np.float64(1756056.1900000006)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.5649177028963924),
#  'meanPL': np.float64(-15.126705427135821),
#  'return': np.float64(-0.0012831686959638218),
#  'score': np.float64(-57.37983084046897),
#  'stdDev': np.float64(422.5312541333314),
#  'totalVolume': np.float64(2353681.920000003)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.1980410606169712),
#  'meanPL': np.float64(-6.07874223618052),
#  'return': np.float64(-0.00045916456851219736),
#  'score': np.float64(-54.51361440777464),
#  'stdDev': np.float64(484.34872171594117),
#  'totalVolume': np.float64(2669250.5999999987)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-1.347689714947617),
#  'meanPL': np.float64(-28.694012437185837),
#  'return': np.float64(-0.007269119239628828),
#  'score': np.float64(-62.291054395939724),
#  'stdDev': np.float64(335.9704195875388),
#  'totalVolume': np.float64(785938.29)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-1.6183103789744986),
#  'meanPL': np.float64(-44.819008618090244),
#  'return': np.float64(-0.007853566209126712),
#  'score': np.float64(-88.5208865809148),
#  'stdDev': np.float64(437.01877962824557),
#  'totalVolume': np.float64(1136293.57)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-1.9076477843862067),
#  'meanPL': np.float64(-60.62656743718583),
#  'return': np.float64(-0.008451050149397317),
#  'score': np.float64(-110.77581959495615),
#  'stdDev': np.float64(501.4925215777031),
#  'totalVolume': np.float64(1428539.5999999994)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-1.270547615216662),
#  'meanPL': np.float64(-17.20988738693468),
#  'return': np.float64(-0.01209843826647041),
#  'score': np.float64(-38.58393422283363),
#  'stdDev': np.float64(213.74046835898952),
#  'totalVolume': np.float64(283075.18000000017)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.9549113895645392),
#  'meanPL': np.float64(-17.798223090452264),
#  'return': np.float64(-0.007902859062461152),
#  'score': np.float64(-47.20945707791323),
#  'stdDev': np.float64(294.11233987460963),
#  'totalVolume': np.float64(448172.7900000002)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.8076621564308819),
#  'meanPL': np.float64(-18.752051557789056),
#  'return': np.float64(-0.006403680105719171),
#  'score': np.float64(-55.388952289537414),
#  'stdDev': np.float64(366.3690073174836),
#  'totalVolume': np.float64(582736.52)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 3, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.4118857514501855),
#  'meanPL': np.float64(33.4891277386933),
#  'return': np.float64(0.0017882913966593744),
#  'score': np.float64(-3.9395042623429717),
#  'stdDev': np.float64(374.2863200103627),
#  'totalVolume': np.float64(3719163.570000001)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.808270549682394),
#  'meanPL': np.float64(55.47613723618103),
#  'return': np.float64(0.002239687681186632),
#  'score': np.float64(7.065312865660033),
#  'stdDev': np.float64(484.10824370521),
#  'totalVolume': np.float64(4919133.700000004)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.812412356099312),
#  'meanPL': np.float64(63.793166683416516),
#  'return': np.float64(0.002225965899450096),
#  'score': np.float64(8.251766981321445),
#  'stdDev': np.float64(555.4139970209507),
#  'totalVolume': np.float64(5686949.35)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.3699053061683788),
#  'meanPL': np.float64(35.47516706030159),
#  'return': np.float64(0.006552191875750525),
#  'score': np.float64(-5.388146013357648),
#  'stdDev': np.float64(408.6331307365923),
#  'totalVolume': np.float64(1076757.4300000002)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.2340567004037695),
#  'meanPL': np.float64(39.179160226130584),
#  'return': np.float64(0.0052943930277481056),
#  'score': np.float64(-10.918758302632924),
#  'stdDev': np.float64(500.97918528763506),
#  'totalVolume': np.float64(1471213.630000001)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.1078670666770547),
#  'meanPL': np.float64(39.499291256281154),
#  'return': np.float64(0.004391752337597393),
#  'score': np.float64(-16.760915546833175),
#  'stdDev': np.float64(562.6020680311433),
#  'totalVolume': np.float64(1787077.39)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.016176903013038),
#  'meanPL': np.float64(11.216702010050223),
#  'return': np.float64(0.0075313168484382464),
#  'score': np.float64(-6.201187703306957),
#  'stdDev': np.float64(174.17889713357178),
#  'totalVolume': np.float64(296183.0599999998)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.9902258041973186),
#  'meanPL': np.float64(16.765579648241168),
#  'return': np.float64(0.006684499415893362),
#  'score': np.float64(-9.951193775420862),
#  'stdDev': np.float64(267.1677342366203),
#  'totalVolume': np.float64(498744.5600000001)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.9480283506140784),
#  'meanPL': np.float64(21.483174497487273),
#  'return': np.float64(0.006080606100191927),
#  'score': np.float64(-14.275120636550948),
#  'stdDev': np.float64(357.5829513403822),
#  'totalVolume': np.float64(702423.1399999998)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.3750950467999428),
#  'meanPL': np.float64(-2.357930402010063),
#  'return': np.float64(-0.007172954600000346),
#  'score': np.float64(-12.277420000664264),
#  'stdDev': np.float64(99.194895986542),
#  'totalVolume': np.float64(65416.3)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.3487026900908191),
#  'meanPL': np.float64(-3.6092201758793956),
#  'return': np.float64(-0.006069779944380792),
#  'score': np.float64(-19.941911421679062),
#  'stdDev': np.float64(163.32691245799666),
#  'totalVolume': np.float64(118329.63)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.3740380948887582),
#  'meanPL': np.float64(-5.478313165829155),
#  'return': np.float64(-0.0063379625581598785),
#  'score': np.float64(-28.589949338618176),
#  'stdDev': np.float64(231.11636172789022),
#  'totalVolume': np.float64(172008.64)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.6657531349112767),
#  'meanPL': np.float64(-1.7391305025125643),
#  'return': np.float64(-0.03882536454138129),
#  'score': np.float64(-5.861231473611438),
#  'stdDev': np.float64(41.22100971098874),
#  'totalVolume': np.float64(8913.939999999999)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.6510832172593579),
#  'meanPL': np.float64(-2.847313618090463),
#  'return': np.float64(-0.03789861760090766),
#  'score': np.float64(-9.748098319019402),
#  'stdDev': np.float64(69.00784700928939),
#  'totalVolume': np.float64(14950.819999999998)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.6605873994163459),
#  'meanPL': np.float64(-4.620748442211056),
#  'return': np.float64(-0.03847742728643713),
#  'score': np.float64(-15.658527941962486),
#  'stdDev': np.float64(110.3777949975143),
#  'totalVolume': np.float64(23897.879999999997)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.147702380245314),
#  'meanPL': np.float64(31.08944650753777),
#  'return': np.float64(0.0008425658402097329),
#  'score': np.float64(-11.655362556696776),
#  'stdDev': np.float64(427.4480906423454),
#  'totalVolume': np.float64(7312848.0600000005)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.238858265649304),
#  'meanPL': np.float64(41.92018849246178),
#  'return': np.float64(0.0009279725677513424),
#  'score': np.float64(-11.474895932763836),
#  'stdDev': np.float64(533.9508442522562),
#  'totalVolume': np.float64(8943981.340000002)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.0874989653026899),
#  'meanPL': np.float64(40.573062085427246),
#  'return': np.float64(0.0008311092220200509),
#  'score': np.float64(-18.298913073179527),
#  'stdDev': np.float64(588.7197515860677),
#  'totalVolume': np.float64(9633168.929999998)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.31024649464867465),
#  'meanPL': np.float64(-9.337844698492667),
#  'return': np.float64(-0.0005562517838509909),
#  'score': np.float64(-56.83192005628453),
#  'stdDev': np.float64(474.9407535779186),
#  'totalVolume': np.float64(3370026.460000001)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.137721762040367),
#  'meanPL': np.float64(-5.035105000000223),
#  'return': np.float64(-0.00024166211749269685),
#  'score': np.float64(-62.725781890554444),
#  'stdDev': np.float64(576.9067689055422),
#  'totalVolume': np.float64(4259692.729999999)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.19440498180231605),
#  'meanPL': np.float64(-7.8435280150757105),
#  'return': np.float64(-0.00034326035069439157),
#  'score': np.float64(-71.50896666886196),
#  'stdDev': np.float64(636.6543865378625),
#  'totalVolume': np.float64(4675013.649999999)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.5858342230226388),
#  'meanPL': np.float64(-14.11576188442214),
#  'return': np.float64(-0.0017205675925507776),
#  'score': np.float64(-52.137262968526436),
#  'stdDev': np.float64(380.21501084104295),
#  'totalVolume': np.float64(1635206.4500000011)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.9322067143457362),
#  'meanPL': np.float64(-27.477298165829232),
#  'return': np.float64(-0.002543063756282589),
#  'score': np.float64(-73.9889189226154),
#  'stdDev': np.float64(465.11620756786164),
#  'totalVolume': np.float64(2153089.93)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-1.1199997972141427),
#  'meanPL': np.float64(-37.11480763819094),
#  'return': np.float64(-0.002860258592953091),
#  'score': np.float64(-89.4060479971794),
#  'stdDev': np.float64(522.9124035898847),
#  'totalVolume': np.float64(2586403.0399999996)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.2033593892774652),
#  'meanPL': np.float64(25.322141984924613),
#  'return': np.float64(0.006892444146653686),
#  'score': np.float64(-7.88295570177565),
#  'stdDev': np.float64(332.05097686700265),
#  'totalVolume': np.float64(730460.7100000003)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.5328197647610262),
#  'meanPL': np.float64(42.72319909547724),
#  'return': np.float64(0.008775516042292179),
#  'score': np.float64(-1.2585348262640466),
#  'stdDev': np.float64(439.81733921741284),
#  'totalVolume': np.float64(967972.0200000005)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.5546374530701907),
#  'meanPL': np.float64(49.340300628140724),
#  'return': np.float64(0.008926539419199698),
#  'score': np.float64(-0.7406240185877309),
#  'stdDev': np.float64(500.80924646728454),
#  'totalVolume': np.float64(1098609.9499999995)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.8421920786175947),
#  'meanPL': np.float64(20.73988258793974),
#  'return': np.float64(0.013043446719380361),
#  'score': np.float64(2.9746435084252205),
#  'stdDev': np.float64(177.65239079514518),
#  'totalVolume': np.float64(316194.99000000017)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.974713903450681),
#  'meanPL': np.float64(35.49385668341698),
#  'return': np.float64(0.013496513692539245),
#  'score': np.float64(7.131084214360051),
#  'stdDev': np.float64(283.62772469056927),
#  'totalVolume': np.float64(522971.6600000001)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(2.2836869622867515),
#  'meanPL': np.float64(52.986437964824184),
#  'return': np.float64(0.015966287344700854),
#  'score': np.float64(16.374069373178727),
#  'stdDev': np.float64(366.1236859164545),
#  'totalVolume': np.float64(659912.5699999997)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.1129696385624688),
#  'meanPL': np.float64(3.160386633166115),
#  'return': np.float64(6.334428965390486e-05),
#  'score': np.float64(-40.984270755593826),
#  'stdDev': np.float64(441.44657388759936),
#  'totalVolume': np.float64(9318493.320000006)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.18889456810189714),
#  'meanPL': np.float64(6.548142261306595),
#  'return': np.float64(0.00011117628516501921),
#  'score': np.float64(-48.15324119056058),
#  'stdDev': np.float64(547.0138345186717),
#  'totalVolume': np.float64(11138652.080000006)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.4020611091456806),
#  'meanPL': np.float64(15.009750251256584),
#  'return': np.float64(0.0002441743531519515),
#  'score': np.float64(-43.89917144073346),
#  'stdDev': np.float64(589.0892169199004),
#  'totalVolume': np.float64(11808093.040000001)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.4663651456624099),
#  'meanPL': np.float64(13.309393618090509),
#  'return': np.float64(0.0005101530670730221),
#  'score': np.float64(-31.72370776025805),
#  'stdDev': np.float64(450.33101378348556),
#  'totalVolume': np.float64(5153832.79)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.7704998362064469),
#  'meanPL': np.float64(26.290035427136342),
#  'return': np.float64(0.0009052464099618398),
#  'score': np.float64(-27.55160634087203),
#  'stdDev': np.float64(538.4164176800837),
#  'totalVolume': np.float64(5743533.620000002)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.5702267649317644),
#  'meanPL': np.float64(20.814928869346847),
#  'return': np.float64(0.000678723952999471),
#  'score': np.float64(-36.78567103510312),
#  'stdDev': np.float64(576.0059990444996),
#  'totalVolume': np.float64(6026449.18)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-1.1314964550050073),
#  'meanPL': np.float64(-31.49166618090473),
#  'return': np.float64(-0.002167525281822966),
#  'score': np.float64(-75.40962175677944),
#  'stdDev': np.float64(439.17955575874714),
#  'totalVolume': np.float64(2898096.99)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-1.3922552228100344),
#  'meanPL': np.float64(-45.79543185929633),
#  'return': np.float64(-0.0024574322988419784),
#  'score': np.float64(-97.69968862912614),
#  'stdDev': np.float64(519.0425676982981),
#  'totalVolume': np.float64(3718606.2599999993)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-1.5632562328646054),
#  'meanPL': np.float64(-56.027994296482724),
#  'return': np.float64(-0.0026556057780535167),
#  'score': np.float64(-112.58345967011007),
#  'stdDev': np.float64(565.5546537362734),
#  'totalVolume': np.float64(4213525.54)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.8922641197397603),
#  'meanPL': np.float64(46.20416216080399),
#  'return': np.float64(0.005387681616095249),
#  'score': np.float64(7.674161327289404),
#  'stdDev': np.float64(385.30000833514583),
#  'totalVolume': np.float64(1705776.6800000013)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.5557457449218803),
#  'meanPL': np.float64(48.03035150753756),
#  'return': np.float64(0.004131506279146545),
#  'score': np.float64(-0.6862312252945202),
#  'stdDev': np.float64(487.1658273283208),
#  'totalVolume': np.float64(2311645.3599999994)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.4947849312209056),
#  'meanPL': np.float64(51.43463301507526),
#  'return': np.float64(0.003711117946985089),
#  'score': np.float64(-2.862463649743205),
#  'stdDev': np.float64(542.9709666481847),
#  'totalVolume': np.float64(2754845.6599999988)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.6023074219466291),
#  'meanPL': np.float64(31.154922889447256),
#  'return': np.float64(0.006589473702291909),
#  'score': np.float64(0.47314583423740686),
#  'stdDev': np.float64(306.81777055209847),
#  'totalVolume': np.float64(940193.9099999998)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.9721286657744759),
#  'meanPL': np.float64(52.1545482663315),
#  'return': np.float64(0.007497744161497894),
#  'score': np.float64(10.423757351442397),
#  'stdDev': np.float64(417.30790914889104),
#  'totalVolume': np.float64(1383255.0499999989)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.9866572969921967),
#  'meanPL': np.float64(61.84418417085411),
#  'return': np.float64(0.007420141428014718),
#  'score': np.float64(12.722236106358942),
#  'stdDev': np.float64(491.21948064495166),
#  'totalVolume': np.float64(1656984.3)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 4, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.1411411865663448),
#  'meanPL': np.float64(33.8616235175882),
#  'return': np.float64(0.0021435065298255848),
#  'score': np.float64(-12.962328918997756),
#  'stdDev': np.float64(468.23952436585955),
#  'totalVolume': np.float64(3137416.120000001)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.207944029079973),
#  'meanPL': np.float64(42.52855409547765),
#  'return': np.float64(0.0022120671306436602),
#  'score': np.float64(-13.027767057521942),
#  'stdDev': np.float64(555.5632115299959),
#  'totalVolume': np.float64(3815794.1900000013)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.5221317281716573),
#  'meanPL': np.float64(58.00448444723586),
#  'return': np.float64(0.002733513007073129),
#  'score': np.float64(-2.1279803750217567),
#  'stdDev': np.float64(601.3246482225761),
#  'totalVolume': np.float64(4209604.220000001)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.009442069764757088),
#  'meanPL': np.float64(0.18812309045222436),
#  'return': np.float64(2.8858811249868613e-05),
#  'score': np.float64(-31.251300363179322),
#  'stdDev': np.float64(314.3942345363154),
#  'totalVolume': np.float64(1194383.0500000003)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.06138661581377732),
#  'meanPL': np.float64(1.5741106783918495),
#  'return': np.float64(0.0001850759641097554),
#  'score': np.float64(-38.88918446728371),
#  'stdDev': np.float64(404.63295145675556),
#  'totalVolume': np.float64(1665610.9100000013)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.3001707702426999),
#  'meanPL': np.float64(8.971715753769013),
#  'return': np.float64(0.0009002237710167776),
#  'score': np.float64(-38.19186601361441),
#  'stdDev': np.float64(471.6358176738342),
#  'totalVolume': np.float64(1974420.1300000001)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.4120713402410271),
#  'meanPL': np.float64(4.851189221105519),
#  'return': np.float64(0.0031711838159709993),
#  'score': np.float64(-13.725806369593093),
#  'stdDev': np.float64(185.7699559069861),
#  'totalVolume': np.float64(303956.45000000007)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.5638525296682837),
#  'meanPL': np.float64(10.494210829145638),
#  'return': np.float64(0.004348851692935518),
#  'score': np.float64(-18.874435228329794),
#  'stdDev': np.float64(293.6864605747543),
#  'totalVolume': np.float64(479635.20999999985)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.6778138561736189),
#  'meanPL': np.float64(16.766285879397067),
#  'return': np.float64(0.005129329023235549),
#  'score': np.float64(-22.266189809906834),
#  'stdDev': np.float64(390.32475689303897),
#  'totalVolume': np.float64(649699.1000000002)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.420794087915861),
#  'meanPL': np.float64(6.9775658542713455),
#  'return': np.float64(0.01944866693167483),
#  'score': np.float64(-0.7719126207865008),
#  'stdDev': np.float64(77.49478475057846),
#  'totalVolume': np.float64(71318.54999999999)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(1.37289419131793),
#  'meanPL': np.float64(11.181126884422078),
#  'return': np.float64(0.018487025902446587),
#  'score': np.float64(-1.6702062599319163),
#  'stdDev': np.float64(128.51333144353993),
#  'totalVolume': np.float64(120222.62000000002)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.175915691308386),
#  'meanPL': np.float64(14.81999640703518),
#  'return': np.float64(0.016307703068692767),
#  'score': np.float64(-5.06710948946095),
#  'stdDev': np.float64(198.8710589649613),
#  'totalVolume': np.float64(180602.3099999999)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.8957105286505382),
#  'meanPL': np.float64(2.737057864321606),
#  'return': np.float64(0.04596033193907329),
#  'score': np.float64(-2.0848174198097387),
#  'stdDev': np.float64(48.218752841313446),
#  'totalVolume': np.float64(11850.970000000001)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.8821417709565551),
#  'meanPL': np.float64(4.533340100502511),
#  'return': np.float64(0.042977950172076694),
#  'score': np.float64(-3.57588933840755),
#  'stdDev': np.float64(81.09229438910062),
#  'totalVolume': np.float64(20990.639999999996)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 2, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.8646763594170478),
#  'meanPL': np.float64(6.0778453768844205),
#  'return': np.float64(0.04128303024759074),
#  'score': np.float64(-5.013793860341348),
#  'stdDev': np.float64(110.91639237225768),
#  'totalVolume': np.float64(29297.54)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.1777092450604922),
#  'meanPL': np.float64(32.41842278894465),
#  'return': np.float64(0.0009609873445207442),
#  'score': np.float64(-11.017941933907927),
#  'stdDev': np.float64(434.3636472285258),
#  'totalVolume': np.float64(6688435.760000001)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.6454599959221469),
#  'meanPL': np.float64(21.434097713568075),
#  'return': np.float64(0.0005275315604985172),
#  'score': np.float64(-30.966416511307198),
#  'stdDev': np.float64(524.0051422487527),
#  'totalVolume': np.float64(8010089.73)}
#
# Testing parameters: {'roc_period': 5, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.5642221233065323),
#  'meanPL': np.float64(20.511898592965142),
#  'return': np.float64(0.00046443074872267576),
#  'score': np.float64(-36.854214315445475),
#  'stdDev': np.float64(573.6611290841062),
#  'totalVolume': np.float64(8651590.599999998)}
#
# ...
# Statistics:
# {'annualSharpe': np.float64(1.0519402826673117),
#  'meanPL': np.float64(26.217766733668263),
#  'return': np.float64(0.0030729310829916453),
#  'score': np.float64(-13.110452529559268),
#  'stdDev': np.float64(393.28219263227527),
#  'totalVolume': np.float64(1695423.13)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.6887556101037078),
#  'meanPL': np.float64(21.451493341708733),
#  'return': np.float64(0.0019524107291454711),
#  'score': np.float64(-27.69494559765623),
#  'stdDev': np.float64(491.4643893936496),
#  'totalVolume': np.float64(2180087.510000002)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.6894654793012388),
#  'meanPL': np.float64(24.297562361809067),
#  'return': np.float64(0.002005027436989333),
#  'score': np.float64(-31.312048052852713),
#  'stdDev': np.float64(556.0961041466178),
#  'totalVolume': np.float64(2401606.4300000006)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.062473361487249565),
#  'meanPL': np.float64(-1.1959646231155228),
#  'return': np.float64(-0.00032616751131460175),
#  'score': np.float64(-31.404045288584037),
#  'stdDev': np.float64(302.08080665468515),
#  'totalVolume': np.float64(743301.7900000003)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.1420152669244577),
#  'meanPL': np.float64(-3.5688589698493893),
#  'return': np.float64(-0.0006566932977864428),
#  'score': np.float64(-43.22350024144634),
#  'stdDev': np.float64(396.5464127159695),
#  'totalVolume': np.float64(1092835.5100000002)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.37624914474267757),
#  'meanPL': np.float64(-11.385956633165966),
#  'return': np.float64(-0.0016302348350104047),
#  'score': np.float64(-59.138188810577084),
#  'stdDev': np.float64(477.52232177411116),
#  'totalVolume': np.float64(1397205.2099999997)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.6120423679247875),
#  'meanPL': np.float64(9.420221306532717),
#  'return': np.float64(0.007334824461331122),
#  'score': np.float64(-14.867081779480195),
#  'stdDev': np.float64(242.8730308601291),
#  'totalVolume': np.float64(255174.83000000005)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.5192544009774297),
#  'meanPL': np.float64(10.68253464824122),
#  'return': np.float64(0.005227342360675801),
#  'score': np.float64(-21.780849994775426),
#  'stdDev': np.float64(324.63384643016644),
#  'totalVolume': np.float64(405722.20999999996)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 3, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.25272246738425913),
#  'meanPL': np.float64(6.349261407035213),
#  'return': np.float64(0.002370997580116299),
#  'score': np.float64(-33.29488108186451),
#  'stdDev': np.float64(396.44142488899723),
#  'totalVolume': np.float64(529533.7100000002)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.7434344842055055),
#  'meanPL': np.float64(-21.952034145728472),
#  'return': np.float64(-0.0005600599937109662),
#  'score': np.float64(-68.54622144574017),
#  'stdDev': np.float64(465.94187300011697),
#  'totalVolume': np.float64(7866301.190000002)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.6777948114472202),
#  'meanPL': np.float64(-23.573614095477538),
#  'return': np.float64(-0.0005273415013527172),
#  'score': np.float64(-78.4553201435814),
#  'stdDev': np.float64(548.8170604810387),
#  'totalVolume': np.float64(9013769.830000004)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.5227333042733123),
#  'meanPL': np.float64(-19.58871540201021),
#  'return': np.float64(-0.00042347706302714124),
#  'score': np.float64(-78.72110906170357),
#  'stdDev': np.float64(591.3239365969337),
#  'totalVolume': np.float64(9440568.129999999)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.32200080878391435),
#  'meanPL': np.float64(-9.4521262060301),
#  'return': np.float64(-0.0003853053181742611),
#  'score': np.float64(-55.7725178529324),
#  'stdDev': np.float64(463.203916469023),
#  'totalVolume': np.float64(4939636.179999997)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.23908423523916736),
#  'meanPL': np.float64(-8.224297638190826),
#  'return': np.float64(-0.0002848654538361282),
#  'score': np.float64(-62.5052616698888),
#  'stdDev': np.float64(542.8096403169798),
#  'totalVolume': np.float64(5876136.69)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.4921273480721791),
#  'meanPL': np.float64(-18.210222864321704),
#  'return': np.float64(-0.0005801092345452822),
#  'score': np.float64(-76.60008293944126),
#  'stdDev': np.float64(583.8986007511955),
#  'totalVolume': np.float64(6349954.570000002)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.47133043681940784),
#  'meanPL': np.float64(12.61879052763819),
#  'return': np.float64(0.0007690080529121812),
#  'score': np.float64(-29.62782465555464),
#  'stdDev': np.float64(422.46615183192824),
#  'totalVolume': np.float64(3253856.4199999995)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.9257667932041017),
#  'meanPL': np.float64(31.495821608040238),
#  'return': np.float64(0.001544750949701938),
#  'score': np.float64(-22.188938488588832),
#  'stdDev': np.float64(536.8476009662907),
#  'totalVolume': np.float64(4047759.4600000014)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(1.0694180453488151),
#  'meanPL': np.float64(41.21449361809069),
#  'return': np.float64(0.0018997321788023517),
#  'score': np.float64(-19.599305287999883),
#  'stdDev': np.float64(608.1379890609057),
#  'totalVolume': np.float64(4304692.87)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.3712623321598374),
#  'meanPL': np.float64(-9.73730839195987),
#  'return': np.float64(-0.001211549597781439),
#  'score': np.float64(-51.12371401796314),
#  'stdDev': np.float64(413.86405626003267),
#  'totalVolume': np.float64(1604273.27)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.2381651213032546),
#  'meanPL': np.float64(-7.678135753768943),
#  'return': np.float64(-0.0007298760270271382),
#  'score': np.float64(-58.549958589947856),
#  'stdDev': np.float64(508.7182283617891),
#  'totalVolume': np.float64(2107048.7700000014)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.22050071771810603),
#  'meanPL': np.float64(-7.88059306532652),
#  'return': np.float64(-0.0006437068720153137),
#  'score': np.float64(-64.2766276650356),
#  'stdDev': np.float64(563.9603459970908),
#  'totalVolume': np.float64(2461051.4099999988)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.14886812186740583),
#  'meanPL': np.float64(2.7905951005024425),
#  'return': np.float64(0.0006446437730402341),
#  'score': np.float64(-26.789174821591757),
#  'stdDev': np.float64(295.797699220942),
#  'totalVolume': np.float64(852247.6800000002)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.06714495899268946),
#  'meanPL': np.float64(1.694984120602963),
#  'return': np.float64(0.00026983116416805784),
#  'score': np.float64(-38.138830188173614),
#  'stdDev': np.float64(398.33814308776573),
#  'totalVolume': np.float64(1213227.06)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 4, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.25801885045393447),
#  'meanPL': np.float64(-7.840708718593127),
#  'return': np.float64(-0.0010771963900927974),
#  'score': np.float64(-55.79235894239772),
#  'stdDev': np.float64(479.5165022380459),
#  'totalVolume': np.float64(1463297.4400000006)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.3621257574316128),
#  'meanPL': np.float64(-12.535923693467412),
#  'return': np.float64(-0.00029437718130538283),
#  'score': np.float64(-67.16157106529141),
#  'stdDev': np.float64(546.2564737182399),
#  'totalVolume': np.float64(8615629.390000002)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.380646547959181),
#  'meanPL': np.float64(-15.127979045226082),
#  'return': np.float64(-0.00032461264950423057),
#  'score': np.float64(-77.84114014474771),
#  'stdDev': np.float64(627.1316109952163),
#  'totalVolume': np.float64(9488597.639999999)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.01, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.29487973388360733),
#  'meanPL': np.float64(-12.371645301506591),
#  'return': np.float64(-0.0002637811696412333),
#  'score': np.float64(-78.57533703222065),
#  'stdDev': np.float64(662.0369173071406),
#  'totalVolume': np.float64(9756673.489999995)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.7556007073224539),
#  'meanPL': np.float64(-22.569748216080484),
#  'return': np.float64(-0.0007515111020575859),
#  'score': np.float64(-69.70371939826771),
#  'stdDev': np.float64(471.33971182187224),
#  'totalVolume': np.float64(6006056.940000005)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.8554737901074297),
#  'meanPL': np.float64(-28.943419773869724),
#  'return': np.float64(-0.000837687377612469),
#  'score': np.float64(-82.33131612748426),
#  'stdDev': np.float64(533.8789635361453),
#  'totalVolume': np.float64(6920276.429999995)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.015, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.5104519298158312),
#  'meanPL': np.float64(-18.669984020100156),
#  'return': np.float64(-0.0005284142485469189),
#  'score': np.float64(-76.38499328733862),
#  'stdDev': np.float64(577.1500926723846),
#  'totalVolume': np.float64(7144302.960000003)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.07986125523501665),
#  'meanPL': np.float64(-2.285853542713816),
#  'return': np.float64(-0.0001179775220884613),
#  'score': np.float64(-47.451886045786416),
#  'stdDev': np.float64(451.66032503072597),
#  'totalVolume': np.float64(3969085.8200000003)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.34791487605158294),
#  'meanPL': np.float64(-11.451606758794243),
#  'return': np.float64(-0.0004825089511470028),
#  'score': np.float64(-63.39054904337329),
#  'stdDev': np.float64(519.3894228457905),
#  'totalVolume': np.float64(4769296.6099999985)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.02, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.29213073369997766),
#  'meanPL': np.float64(-10.494630050251265),
#  'return': np.float64(-0.00041044603941175323),
#  'score': np.float64(-67.1824241842098),
#  'stdDev': np.float64(566.8779413395853),
#  'totalVolume': np.float64(5175650.49)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.23195481572424337),
#  'meanPL': np.float64(6.356947286432018),
#  'return': np.float64(0.0004952253518779454),
#  'score': np.float64(-36.88894777690879),
#  'stdDev': np.float64(432.45895063340805),
#  'totalVolume': np.float64(2530441.9700000007)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.5230347185593872),
#  'meanPL': np.float64(17.172568643215914),
#  'return': np.float64(0.001091926123006293),
#  'score': np.float64(-34.63633674878547),
#  'stdDev': np.float64(518.0890539200138),
#  'totalVolume': np.float64(3111450.9200000023)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.025, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.9167142528818444),
#  'meanPL': np.float64(33.018750577889264),
#  'return': np.float64(0.0019053087917684948),
#  'score': np.float64(-23.81761845929219),
#  'stdDev': np.float64(568.3636903718145),
#  'totalVolume': np.float64(3431891.9999999995)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.3052483353684918),
#  'meanPL': np.float64(-8.18927464824128),
#  'return': np.float64(-0.0011294856319031842),
#  'score': np.float64(-50.52351837802855),
#  'stdDev': np.float64(423.34243729787266),
#  'totalVolume': np.float64(1449405.6000000008)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.17812552074650206),
#  'meanPL': np.float64(-5.688392211055237),
#  'return': np.float64(-0.0005863235873871641),
#  'score': np.float64(-56.080562115044195),
#  'stdDev': np.float64(503.9216990398895),
#  'totalVolume': np.float64(1951841.9599999993)}
#
# Testing parameters: {'roc_period': 7, 'ma_period': 5, 'roc_threshold': 0.03, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.05876756359456904),
#  'meanPL': np.float64(-2.055899924623035),
#  'return': np.float64(-0.00019543553047105702),
#  'score': np.float64(-57.25906239031379),
#  'stdDev': np.float64(552.0316246569075),
#  'totalVolume': np.float64(2195364.42)}
#
# ==================================================
# GRID SEARCH COMPLETE
# ==================================================
# Best parameters: {'roc_period': 6, 'ma_period': 3, 'roc_threshold': 0.01, 'capital_allocation': 5000}
# Best statistics:
# {'annualSharpe': np.float64(2.1398065941379114),
#  'meanPL': np.float64(74.51871223618114),
#  'return': np.float64(0.001953619604945573),
#  'score': np.float64(19.565827790303054),
#  'stdDev': np.float64(549.5288444587809),
#  'totalVolume': np.float64(7566445.8999999985)}
# ({'roc_period': 6,
#   'ma_period': 3,
#   'roc_threshold': 0.01,
#   'capital_allocation': 5000},
#  {'meanPL': np.float64(74.51871223618114),
#   'return': np.float64(0.001953619604945573),
#   'stdDev': np.float64(549.5288444587809),
#   'annualSharpe': np.float64(2.1398065941379114),
#   'totalVolume': np.float64(7566445.8999999985),
#   'score': np.float64(19.565827790303054)})

# %%
# 2. Linear Regression Strategy
bt.set_getPos(LinearRegressionStrategy)
param_ranges_lr = {
    "look_back_period": [5, 7, 10, 14],
    "min_threshold": [0.001, 0.002, 0.005],
    "capital_allocation": [3000, 5000, 8000],
}
print("Gridsearch: Linear Regression Strategy")
bt.gridsearch(param_ranges_lr, numTestDays=NUM_TEST_DAYS)
# Out:
# Gridsearch: Linear Regression Strategy
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.001, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.8022684055750364),
#  'meanPL': np.float64(0.0019474371859296371),
#  'return': np.float64(0.005969500924214385),
#  'score': np.float64(0.0002423614954691778),
#  'stdDev': np.float64(0.017050756904604593),
#  'totalVolume': np.float64(64.91999999999999)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.001, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.3764151095077622),
#  'meanPL': np.float64(0.0012516582914572918),
#  'return': np.float64(0.0005576657776142779),
#  'score': np.float64(-0.003995430413675859),
#  'stdDev': np.float64(0.052470887051331495),
#  'totalVolume': np.float64(434.92)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.001, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.372390362569192),
#  'meanPL': np.float64(-0.0037619849246230807),
#  'return': np.float64(-0.00035994790061902863),
#  'score': np.float64(-0.019703085119533358),
#  'stdDev': np.float64(0.15941100194910274),
#  'totalVolume': np.float64(2142.059999999999)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.002, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.8022684055750364),
#  'meanPL': np.float64(0.0019474371859296371),
#  'return': np.float64(0.005969500924214385),
#  'score': np.float64(0.0002423614954691778),
#  'stdDev': np.float64(0.017050756904604593),
#  'totalVolume': np.float64(64.91999999999999)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.002, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.3764151095077622),
#  'meanPL': np.float64(0.0012516582914572918),
#  'return': np.float64(0.0005576657776142779),
#  'score': np.float64(-0.003995430413675859),
#  'stdDev': np.float64(0.052470887051331495),
#  'totalVolume': np.float64(434.92)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.002, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.41819160688104434),
#  'meanPL': np.float64(-0.003921658291457339),
#  'return': np.float64(-0.00038865274664627586),
#  'score': np.float64(-0.018719354616486328),
#  'stdDev': np.float64(0.1479769632502899),
#  'totalVolume': np.float64(2065.609999999999)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.005, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.005, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'look_back_period': 5, 'min_threshold': 0.005, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.2541514972225404),
#  'meanPL': np.float64(0.0008594723618089908),
#  'return': np.float64(0.0006153887669556695),
#  'score': np.float64(-0.0044768114133122965),
#  'stdDev': np.float64(0.053362837751212866),
#  'totalVolume': np.float64(277.92999999999995)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.001, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.5830012719394002),
#  'meanPL': np.float64(0.001567085427135686),
#  'return': np.float64(0.0022879677182685364),
#  'score': np.float64(4.9773366344457726e-06),
#  'stdDev': np.float64(0.0156210809050124),
#  'totalVolume': np.float64(136.3)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.001, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.44591460322813853),
#  'meanPL': np.float64(0.0020408793969849464),
#  'return': np.float64(0.0005701902084730599),
#  'score': np.float64(-0.00518125090483999),
#  'stdDev': np.float64(0.07222130301824936),
#  'totalVolume': np.float64(700.8099999999998)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.001, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.322872648243806),
#  'meanPL': np.float64(0.0040743969849244815),
#  'return': np.float64(0.00019403767492455872),
#  'score': np.float64(-0.01583837677352405),
#  'stdDev': np.float64(0.1991277375844853),
#  'totalVolume': np.float64(4063.180000000001)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.002, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.5830012719394002),
#  'meanPL': np.float64(0.001567085427135686),
#  'return': np.float64(0.0022879677182685364),
#  'score': np.float64(4.9773366344457726e-06),
#  'stdDev': np.float64(0.0156210809050124),
#  'totalVolume': np.float64(136.3)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.002, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.44591460322813853),
#  'meanPL': np.float64(0.0020408793969849464),
#  'return': np.float64(0.0005701902084730599),
#  'score': np.float64(-0.00518125090483999),
#  'stdDev': np.float64(0.07222130301824936),
#  'totalVolume': np.float64(700.8099999999998)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.002, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.05822332094110106),
#  'meanPL': np.float64(0.0006977135678391061),
#  'return': np.float64(3.026955368978687e-05),
#  'score': np.float64(-0.018211778741679716),
#  'stdDev': np.float64(0.1890949230951882),
#  'totalVolume': np.float64(3847.1)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.005, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-1.232803767960582),
#  'meanPL': np.float64(-0.0003722613065326562),
#  'return': np.float64(-0.002630681818181768),
#  'score': np.float64(-0.0008487511168299767),
#  'stdDev': np.float64(0.004764898102973204),
#  'totalVolume': np.float64(28.16)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.005, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-1.6229453552448596),
#  'meanPL': np.float64(-0.0012425628140703535),
#  'return': np.float64(-0.0026155066638459947),
#  'score': np.float64(-0.00245069409339751),
#  'stdDev': np.float64(0.012081312793271567),
#  'totalVolume': np.float64(94.53999999999999)}
#
# Testing parameters: {'look_back_period': 7, 'min_threshold': 0.005, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(0.2597669657937931),
#  'meanPL': np.float64(0.0017048492462310718),
#  'return': np.float64(0.00033213408127500885),
#  'score': np.float64(-0.008651381869351939),
#  'stdDev': np.float64(0.1035623111558301),
#  'totalVolume': np.float64(1021.47)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.001, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.9872064610149723),
#  'meanPL': np.float64(-0.0014073618090452195),
#  'return': np.float64(-0.00155479376006217),
#  'score': np.float64(-0.003656921109715829),
#  'stdDev': np.float64(0.022495593006706092),
#  'totalVolume': np.float64(180.13)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.001, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.3690822067957315),
#  'meanPL': np.float64(0.0018725376884422057),
#  'return': np.float64(0.00025286121797749673),
#  'score': np.float64(-0.006133306478872696),
#  'stdDev': np.float64(0.080058441673149),
#  'totalVolume': np.float64(1447.8100000000004)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.001, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.963734488331811),
#  'meanPL': np.float64(-0.01868364321608003),
#  'return': np.float64(-0.0004300895655811362),
#  'score': np.float64(-0.04927535915491049),
#  'stdDev': np.float64(0.30591715938830466),
#  'totalVolume': np.float64(8725.450000000004)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.002, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-0.9872064610149723),
#  'meanPL': np.float64(-0.0014073618090452195),
#  'return': np.float64(-0.00155479376006217),
#  'score': np.float64(-0.003656921109715829),
#  'stdDev': np.float64(0.022495593006706092),
#  'totalVolume': np.float64(180.13)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.002, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.3690822067957315),
#  'meanPL': np.float64(0.0018725376884422057),
#  'return': np.float64(0.00025286121797749673),
#  'score': np.float64(-0.006133306478872696),
#  'stdDev': np.float64(0.080058441673149),
#  'totalVolume': np.float64(1447.8100000000004)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.002, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.9306320105417099),
#  'meanPL': np.float64(-0.017957688442210806),
#  'return': np.float64(-0.0004246750434295395),
#  'score': np.float64(-0.04840662430032071),
#  'stdDev': np.float64(0.30448935858109905),
#  'totalVolume': np.float64(8496.520000000002)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.005, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(-1.232803767960582),
#  'meanPL': np.float64(-0.0003722613065326562),
#  'return': np.float64(-0.002630681818181768),
#  'score': np.float64(-0.0008487511168299767),
#  'stdDev': np.float64(0.004764898102973204),
#  'totalVolume': np.float64(28.16)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.005, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.19181634977824763),
#  'meanPL': np.float64(-0.0005853517587940276),
#  'return': np.float64(-0.0002185582678199739),
#  'score': np.float64(-0.0054007363524889804),
#  'stdDev': np.float64(0.04815384593694953),
#  'totalVolume': np.float64(532.97)}
#
# Testing parameters: {'look_back_period': 10, 'min_threshold': 0.005, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.8320585696695633),
#  'meanPL': np.float64(-0.010855150753768856),
#  'return': np.float64(-0.0005951958723069775),
#  'score': np.float64(-0.031441608956405805),
#  'stdDev': np.float64(0.2058645820263695),
#  'totalVolume': np.float64(3676.6300000000006)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.001, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.052015199412611),
#  'meanPL': np.float64(0.0028578391959798426),
#  'return': np.float64(0.001131581041824165),
#  'score': np.float64(-0.0014287853594177448),
#  'stdDev': np.float64(0.04286624555397587),
#  'totalVolume': np.float64(502.5799999999999)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.001, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.21967386050478926),
#  'meanPL': np.float64(-0.0015575628140701843),
#  'return': np.float64(-0.00011580539994656623),
#  'score': np.float64(-0.012745933877249377),
#  'stdDev': np.float64(0.11188371063179191),
#  'totalVolume': np.float64(2732.99)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.001, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-1.4978504082818667),
#  'meanPL': np.float64(-0.04208821608040197),
#  'return': np.float64(-0.0005608399794882348),
#  'score': np.float64(-0.08642781393312027),
#  'stdDev': np.float64(0.44339597852718304),
#  'totalVolume': np.float64(14957.27)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.002, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(1.052015199412611),
#  'meanPL': np.float64(0.0028578391959798426),
#  'return': np.float64(0.001131581041824165),
#  'score': np.float64(-0.0014287853594177448),
#  'stdDev': np.float64(0.04286624555397587),
#  'totalVolume': np.float64(502.5799999999999)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.002, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(-0.21967386050478926),
#  'meanPL': np.float64(-0.0015575628140701843),
#  'return': np.float64(-0.00011580539994656623),
#  'score': np.float64(-0.012745933877249377),
#  'stdDev': np.float64(0.11188371063179191),
#  'totalVolume': np.float64(2732.99)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.002, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-1.4785916726015904),
#  'meanPL': np.float64(-0.041660376884422375),
#  'return': np.float64(-0.0005600256694042452),
#  'score': np.float64(-0.08612090449396523),
#  'stdDev': np.float64(0.44460527609542855),
#  'totalVolume': np.float64(14826.990000000003)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.005, 'capital_allocation': 3000}
# Statistics:
# {'annualSharpe': np.float64(0.6958237683388944),
#  'meanPL': np.float64(0.0007935175879396862),
#  'return': np.float64(0.00077338622783817),
#  'score': np.float64(-0.0010060036275254265),
#  'stdDev': np.float64(0.017995212154651125),
#  'totalVolume': np.float64(204.18)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.005, 'capital_allocation': 5000}
# Statistics:
# {'annualSharpe': np.float64(0.5731741018613044),
#  'meanPL': np.float64(0.0022702763819095885),
#  'return': np.float64(0.00035394420375579395),
#  'score': np.float64(-0.003979893841942351),
#  'stdDev': np.float64(0.06250170223851939),
#  'totalVolume': np.float64(1276.43)}
#
# Testing parameters: {'look_back_period': 14, 'min_threshold': 0.005, 'capital_allocation': 8000}
# Statistics:
# {'annualSharpe': np.float64(-0.8081411252931683),
#  'meanPL': np.float64(-0.017148944723618144),
#  'return': np.float64(-0.0004776075955036065),
#  'score': np.float64(-0.05063391100894632),
#  'stdDev': np.float64(0.33484966285328177),
#  'totalVolume': np.float64(7145.280000000002)}
#
# ==================================================
# GRID SEARCH COMPLETE
# ==================================================
# Best parameters: {'look_back_period': 5, 'min_threshold': 0.001, 'capital_allocation': 3000}
# Best statistics:
# {'annualSharpe': np.float64(1.8022684055750364),
#  'meanPL': np.float64(0.0019474371859296371),
#  'return': np.float64(0.005969500924214385),
#  'score': np.float64(0.0002423614954691778),
#  'stdDev': np.float64(0.017050756904604593),
#  'totalVolume': np.float64(64.91999999999999)}
# ({'look_back_period': 5, 'min_threshold': 0.001, 'capital_allocation': 3000},
#  {'meanPL': np.float64(0.0019474371859296371),
#   'return': np.float64(0.005969500924214385),
#   'stdDev': np.float64(0.017050756904604593),
#   'annualSharpe': np.float64(1.8022684055750364),
#   'totalVolume': np.float64(64.91999999999999),
#   'score': np.float64(0.0002423614954691778)})

# %%
bt.backtest(
    NUM_TEST_DAYS,
    params={
        "momentum_period": 10,
        "momentum_threshold": 0.03,
        "capital_allocation": 8000,
    },
)
# Out:
# (array([[   0.,  293.,  296., ...,  283.,  282.,  283.],
#         [   0., -165., -165., ..., -184., -182., -181.],
#         [   0., -188., -193., ..., -233., -235., -234.],
#         ...,
#         [   0.,  576.,  573., ...,  562.,  571.,  579.],
#         [   0.,  127.,  127., ...,  126.,  125.,  124.],
#         [   0.,  341.,  341., ...,  306.,  306.,  308.]], shape=(50, 200)),
#  [np.float64(1145.0718199999974),
#   np.float64(1000.7015100000572),
#   np.float64(-97.29847500009055),
#   np.float64(377.27820500012604),
#   np.float64(369.995939999877),
#   np.float64(93.55696500011254),
#   np.float64(-487.29847500006144),
#   np.float64(766.8493599999929),
#   np.float64(1913.354135000016),
#   np.float64(1130.5841250000085),
#   np.float64(-88.68566499999724),
#   np.float64(828.143155000027),
#   np.float64(-976.8073800000711),
#   np.float64(1877.0553700000746),
#   np.float64(1770.327124999967),
#   np.float64(-448.53810500002874),
#   np.float64(911.8666050000174),
#   np.float64(894.4393050000945),
#   np.float64(-768.4561900000699),
#   np.float64(605.1028399999777),
#   np.float64(-238.08440999992308),
#   np.float64(425.47357499996724),
#   np.float64(541.6739349999552),
#   np.float64(11.291439999986324),
#   np.float64(135.29629500006558),
#   np.float64(901.4740399999573),
#   np.float64(85.25448500001221),
#   np.float64(477.0097450000176),
#   np.float64(558.0712500000227),
#   np.float64(1138.2079749999684),
#   np.float64(534.5527299999812),
#   np.float64(1314.888249999989),
#   np.float64(-695.0228999999672),
#   np.float64(-822.8856949999754),
#   np.float64(-142.0187750000041),
#   np.float64(973.8149100000592),
#   np.float64(398.90603499991994),
#   np.float64(209.69082000009075),
#   np.float64(1058.517914999975),
#   np.float64(441.03883499991207),
#   np.float64(81.89350000010745),
#   np.float64(1315.0830799999821),
#   np.float64(975.847559999951),
#   np.float64(-16.0573000000295),
#   np.float64(-177.31643999996595),
#   np.float64(509.70345000001544),
#   np.float64(186.35648999997647),
#   np.float64(-377.1061300000147),
#   np.float64(91.84483999999065),
#   np.float64(-11.537330000035581),
#   np.float64(-396.42244999994),
#   np.float64(1352.5248999999749),
#   np.float64(1691.6981000000378),
#   np.float64(860.2429149999807),
#   np.float64(115.59996999999566),
#   np.float64(-467.07255500002066),
#   np.float64(710.0862399999896),
#   np.float64(354.84859000005235),
#   np.float64(-501.40203999997175),
#   np.float64(0.7981599999620812),
#   np.float64(370.95286500001384),
#   np.float64(876.9306299999589),
#   np.float64(67.53246499999659),
#   np.float64(287.51681500003906),
#   np.float64(1210.0732600000047),
#   np.float64(778.6335950000212),
#   np.float64(-419.6394700000383),
#   np.float64(1075.107239999983),
#   np.float64(315.78484000003664),
#   np.float64(963.6344199999876),
#   np.float64(42.05714999996417),
#   np.float64(335.5609750000149),
#   np.float64(513.624225000065),
#   np.float64(1142.5412649999053),
#   np.float64(787.2333650000364),
#   np.float64(-123.47252499999013),
#   np.float64(-886.4556849999208),
#   np.float64(528.7954999999347),
#   np.float64(-105.32948500005296),
#   np.float64(216.46904000006907),
#   np.float64(1400.2651849999238),
#   np.float64(-185.82476999996288),
#   np.float64(94.74995000002673),
#   np.float64(-27.351730000023963),
#   np.float64(-60.91234999996959),
#   np.float64(-434.7328250000137),
#   np.float64(-893.3270100000227),
#   np.float64(319.8620899999514),
#   np.float64(764.2906100000546),
#   np.float64(944.8064699999377),
#   np.float64(-814.762244999918),
#   np.float64(-767.3539950000268),
#   np.float64(721.093090000024),
#   np.float64(1259.4144449999585),
#   np.float64(748.6162850000401),
#   np.float64(-805.5636949999753),
#   np.float64(826.4678549999517),
#   np.float64(427.0645400000067),
#   np.float64(-675.9976999999635),
#   np.float64(-447.9264149999217),
#   np.float64(-275.7171500000841),
#   np.float64(131.71687000000384),
#   np.float64(-189.12092500003928),
#   np.float64(-407.21473500004504),
#   np.float64(17.856160000068485),
#   np.float64(-854.5979099999968),
#   np.float64(136.8442249999207),
#   np.float64(-509.8831999998947),
#   np.float64(458.68316499998036),
#   np.float64(-187.39457000000402),
#   np.float64(1234.559790000014),
#   np.float64(-480.9342850000685),
#   np.float64(879.9462700000295),
#   np.float64(-753.5631099999446),
#   np.float64(-270.1399200001615),
#   np.float64(1384.1641500000842),
#   np.float64(604.8118049999757),
#   np.float64(91.34864000002563),
#   np.float64(-143.3967850000481),
#   np.float64(785.3767300000618),
#   np.float64(-119.37895500000741),
#   np.float64(-1618.81844500007),
#   np.float64(-299.3881899999542),
#   np.float64(629.6785850000306),
#   np.float64(753.8411899999919),
#   np.float64(722.0762699999177),
#   np.float64(1247.3702600000688),
#   np.float64(-195.7388700000156),
#   np.float64(-612.4767799999681),
#   np.float64(-361.7100650000939),
#   np.float64(244.32105500005127),
#   np.float64(768.2044549999555),
#   np.float64(485.60893000006035),
#   np.float64(275.96754999998666),
#   np.float64(-565.5294900000445),
#   np.float64(2195.8215700000437),
#   np.float64(-193.5977250000724),
#   np.float64(-255.87606499996036),
#   np.float64(627.0130949999875),
#   np.float64(-48.33592999994289),
#   np.float64(142.96930499997688),
#   np.float64(-555.624215000018),
#   np.float64(-238.79706499999156),
#   np.float64(-582.4240350000036),
#   np.float64(-852.5048750000424),
#   np.float64(2466.5938899999746),
#   np.float64(1404.6779850001185),
#   np.float64(1576.6115349999745),
#   np.float64(843.9040849999874),
#   np.float64(-113.6398650000774),
#   np.float64(821.5210600000719),
#   np.float64(-3.128820000041742),
#   np.float64(-370.0324349999719),
#   np.float64(-566.4469699999754),
#   np.float64(983.6147449999844),
#   np.float64(575.3666049999738),
#   np.float64(555.3906150000257),
#   np.float64(849.185115000073),
#   np.float64(162.09510999990744),
#   np.float64(696.3201950000512),
#   np.float64(390.09654499999306),
#   np.float64(341.00472999997146),
#   np.float64(354.65582499993616),
#   np.float64(865.5346500000596),
#   np.float64(-289.65988500003004),
#   np.float64(223.29519499998423),
#   np.float64(-41.809984999956214),
#   np.float64(-244.77632999996422),
#   np.float64(499.3471349999745),
#   np.float64(-245.543765000024),
#   np.float64(498.044774999973),
#   np.float64(-101.8949050000374),
#   np.float64(-376.81467999990855),
#   np.float64(488.0882500000298),
#   np.float64(-321.7176600000821),
#   np.float64(765.4270000000251),
#   np.float64(-785.232850000044),
#   np.float64(-59.00087000000349),
#   np.float64(560.9019249999692),
#   np.float64(728.2774650001084),
#   np.float64(28.97292999997444),
#   np.float64(654.7186250000377),
#   np.float64(303.8103949999204),
#   np.float64(163.27295500006585),
#   np.float64(286.73220999997284),
#   np.float64(1769.6061350000236),
#   np.float64(2046.7811049999727),
#   np.float64(-308.05992499989225),
#   np.float64(902.5331999998452),
#   np.float64(1577.7380000000703),
#   np.float64(57.56887500001176),
#   np.float64(168.1228350000165),
#   np.float64(1267.4974699999875),
#   np.float64(292.35804000000644),
#   np.float64(278.9742599999445),
#   np.float64(378.67545000003884),
#   np.float64(8.70025500000338),
#   np.float64(119.71605999996245),
#   np.float64(682.519999999975)],
#  {'meanPL': np.float64(310.80877140703484),
#   'return': np.float64(0.049625441510785386),
#   'stdDev': np.float64(687.2115353336876),
#   'annualSharpe': np.float64(7.136783123053705),
#   'totalVolume': np.float64(1241331.5100000005),
#   'score': np.float64(242.0876178736661)})

# %%
# 5. Statistical Arbitrage Strategy
bt.set_getPos(StatArbStrategy)
param_ranges_stat = {
    "lookback": [40, 60, 80],
    "z_entry": [1.5, 2.0, 2.5],
    "max_pairs": [3, 5, 7],
    "capital_per_pair": [2000, 5000, 8000],
}
print("Gridsearch: Statistical Arbitrage Strategy")
bt.gridsearch(param_ranges_stat, numTestDays=NUM_TEST_DAYS)
# Out:
# Gridsearch: Statistical Arbitrage Strategy
#
# Testing parameters: {'lookback': 40, 'z_entry': 1.5}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.0}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.5}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 1.5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.0}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 1.5}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.0}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.5}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-3.113428602491269),
#  'meanPL': np.float64(-25.253475402010125),
#  'return': np.float64(-0.000810052890312689),
#  'score': np.float64(-38.052648635365806),
#  'stdDev': np.float64(127.99173233355681),
#  'totalVolume': np.float64(6221551.42)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.525381494450213),
#  'meanPL': np.float64(-38.44992012562835),
#  'return': np.float64(-0.0007125508348343409),
#  'score': np.float64(-55.6602420902781),
#  'stdDev': np.float64(172.1032196464975),
#  'totalVolume': np.float64(10783914.360000007)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.5810142908373495),
#  'meanPL': np.float64(-20.433098517587847),
#  'return': np.float64(-0.0007570177070162328),
#  'score': np.float64(-32.92542981691513),
#  'stdDev': np.float64(124.92331299327283),
#  'totalVolume': np.float64(5393752.890000003)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-2.694793011427251),
#  'meanPL': np.float64(-30.86303442211051),
#  'return': np.float64(-0.0007013730989617503),
#  'score': np.float64(-48.93531183082457),
#  'stdDev': np.float64(180.72277408714058),
#  'totalVolume': np.float64(8799834.779999997)}
#
# Testing parameters: {'lookback': 40, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.4968365003185045),
#  'meanPL': np.float64(-20.461365301507513),
#  'return': np.float64(-0.0009158582951723148),
#  'score': np.float64(-29.694708021182453),
#  'stdDev': np.float64(92.3334271967494),
#  'totalVolume': np.float64(4456253.540000003)}
#
# Testing parameters: {'lookback': 40, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.2085520710456388),
#  'meanPL': np.float64(-35.62966698492471),
#  'return': np.float64(-0.0006414307286782519),
#  'score': np.float64(-53.152420217898836),
#  'stdDev': np.float64(175.22753232974122),
#  'totalVolume': np.float64(11107840.669999996)}
#
# Testing parameters: {'lookback': 60, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'lookback': 60, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'lookback': 80, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.0707971103106013),
#  'meanPL': np.float64(-11.561205603015079),
#  'return': np.float64(-0.0006372332390728226),
#  'score': np.float64(-20.370989350264793),
#  'stdDev': np.float64(88.09783747249716),
#  'totalVolume': np.float64(3631846.069999999)}
#
# Testing parameters: {'lookback': 80, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.697325446839124),
#  'meanPL': np.float64(-32.14616640703503),
#  'return': np.float64(-0.0007218819054891504),
#  'score': np.float64(-50.95212660035969),
#  'stdDev': np.float64(188.05960193324663),
#  'totalVolume': np.float64(8901491.97)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'z_entry': 1.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'z_entry': 1.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 1.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'z_entry': 2.0, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'z_entry': 2.0, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 2.0, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'z_entry': 2.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'z_entry': 2.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 2.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'max_pairs': 3, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.2758492750723205),
#  'meanPL': np.float64(-10.14977145728642),
#  'return': np.float64(-0.0007151568760492275),
#  'score': np.float64(-17.187174762829294),
#  'stdDev': np.float64(70.37403305542873),
#  'totalVolume': np.float64(2836256.0900000003)}
#
# Testing parameters: {'max_pairs': 3, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'max_pairs': 3, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.715456924687129),
#  'meanPL': np.float64(-31.73621997487448),
#  'return': np.float64(-0.0008096537465685874),
#  'score': np.float64(-50.17838709882275),
#  'stdDev': np.float64(184.42167123948275),
#  'totalVolume': np.float64(7824223.109999998)}
#
# Testing parameters: {'max_pairs': 5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'max_pairs': 5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'max_pairs': 5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'max_pairs': 7, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.1397586222472142),
#  'meanPL': np.float64(-21.59696168341713),
#  'return': np.float64(-0.0008202206158229433),
#  'score': np.float64(-32.45111794435848),
#  'stdDev': np.float64(108.54156260941346),
#  'totalVolume': np.float64(5260373.369999997)}
#
# Testing parameters: {'max_pairs': 7, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'max_pairs': 7, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.991949812921457),
#  'meanPL': np.float64(-58.83550962311584),
#  'return': np.float64(-0.0009655166919365851),
#  'score': np.float64(-82.09253252140505),
#  'stdDev': np.float64(232.57022898289208),
#  'totalVolume': np.float64(12164676.58)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 1.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-3.113428602491269),
#  'meanPL': np.float64(-25.253475402010125),
#  'return': np.float64(-0.000810052890312689),
#  'score': np.float64(-38.052648635365806),
#  'stdDev': np.float64(127.99173233355681),
#  'totalVolume': np.float64(6221551.42)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 1.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 1.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.525381494450213),
#  'meanPL': np.float64(-38.44992012562835),
#  'return': np.float64(-0.0007125508348343409),
#  'score': np.float64(-55.6602420902781),
#  'stdDev': np.float64(172.1032196464975),
#  'totalVolume': np.float64(10783914.360000007)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.0, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-3.113428602491269),
#  'meanPL': np.float64(-25.253475402010125),
#  'return': np.float64(-0.000810052890312689),
#  'score': np.float64(-38.052648635365806),
#  'stdDev': np.float64(127.99173233355681),
#  'totalVolume': np.float64(6221551.42)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.0, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.0, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.525381494450213),
#  'meanPL': np.float64(-38.44992012562835),
#  'return': np.float64(-0.0007125508348343409),
#  'score': np.float64(-55.6602420902781),
#  'stdDev': np.float64(172.1032196464975),
#  'totalVolume': np.float64(10783914.360000007)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-3.113428602491269),
#  'meanPL': np.float64(-25.253475402010125),
#  'return': np.float64(-0.000810052890312689),
#  'score': np.float64(-38.052648635365806),
#  'stdDev': np.float64(127.99173233355681),
#  'totalVolume': np.float64(6221551.42)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.559875212895484),
#  'meanPL': np.float64(-38.771910351759),
#  'return': np.float64(-0.000720281876076152),
#  'score': np.float64(-55.958198891525946),
#  'stdDev': np.float64(171.8628853976695),
#  'totalVolume': np.float64(10757126.470000008)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 1.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 1.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 1.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.0, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.0, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.0, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 1.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.5810142908373495),
#  'meanPL': np.float64(-20.433098517587847),
#  'return': np.float64(-0.0007570177070162328),
#  'score': np.float64(-32.92542981691513),
#  'stdDev': np.float64(124.92331299327283),
#  'totalVolume': np.float64(5393752.890000003)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 1.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 1.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-2.694793011427251),
#  'meanPL': np.float64(-30.86303442211051),
#  'return': np.float64(-0.0007013730989617503),
#  'score': np.float64(-48.93531183082457),
#  'stdDev': np.float64(180.72277408714058),
#  'totalVolume': np.float64(8799834.779999997)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.0, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.5810142908373495),
#  'meanPL': np.float64(-20.433098517587847),
#  'return': np.float64(-0.0007570177070162328),
#  'score': np.float64(-32.92542981691513),
#  'stdDev': np.float64(124.92331299327283),
#  'totalVolume': np.float64(5393752.890000003)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.0, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.0, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-2.694793011427251),
#  'meanPL': np.float64(-30.86303442211051),
#  'return': np.float64(-0.0007013730989617503),
#  'score': np.float64(-48.93531183082457),
#  'stdDev': np.float64(180.72277408714058),
#  'totalVolume': np.float64(8799834.779999997)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.5, 'max_pairs': 3}
# Statistics:
# {'annualSharpe': np.float64(-2.5810142908373495),
#  'meanPL': np.float64(-20.433098517587847),
#  'return': np.float64(-0.0007570177070162328),
#  'score': np.float64(-32.92542981691513),
#  'stdDev': np.float64(124.92331299327283),
#  'totalVolume': np.float64(5393752.890000003)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.5, 'max_pairs': 5}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.5, 'max_pairs': 7}
# Statistics:
# {'annualSharpe': np.float64(-2.694793011427251),
#  'meanPL': np.float64(-30.86303442211051),
#  'return': np.float64(-0.0007013730989617503),
#  'score': np.float64(-48.93531183082457),
#  'stdDev': np.float64(180.72277408714058),
#  'totalVolume': np.float64(8799834.779999997)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 1.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.4968365003185045),
#  'meanPL': np.float64(-20.461365301507513),
#  'return': np.float64(-0.0009158582951723148),
#  'score': np.float64(-29.694708021182453),
#  'stdDev': np.float64(92.3334271967494),
#  'totalVolume': np.float64(4456253.540000003)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 1.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 1.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.2085520710456388),
#  'meanPL': np.float64(-35.62966698492471),
#  'return': np.float64(-0.0006414307286782519),
#  'score': np.float64(-53.152420217898836),
#  'stdDev': np.float64(175.22753232974122),
#  'totalVolume': np.float64(11107840.669999996)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.0, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.4968365003185045),
#  'meanPL': np.float64(-20.461365301507513),
#  'return': np.float64(-0.0009158582951723148),
#  'score': np.float64(-29.694708021182453),
#  'stdDev': np.float64(92.3334271967494),
#  'totalVolume': np.float64(4456253.540000003)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.0, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.0, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.2085520710456388),
#  'meanPL': np.float64(-35.62966698492471),
#  'return': np.float64(-0.0006414307286782519),
#  'score': np.float64(-53.152420217898836),
#  'stdDev': np.float64(175.22753232974122),
#  'totalVolume': np.float64(11107840.669999996)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.4968365003185045),
#  'meanPL': np.float64(-20.461365301507513),
#  'return': np.float64(-0.0009158582951723148),
#  'score': np.float64(-29.694708021182453),
#  'stdDev': np.float64(92.3334271967494),
#  'totalVolume': np.float64(4456253.540000003)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'z_entry': 2.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.2085520710456388),
#  'meanPL': np.float64(-35.62966698492471),
#  'return': np.float64(-0.0006414307286782519),
#  'score': np.float64(-53.152420217898836),
#  'stdDev': np.float64(175.22753232974122),
#  'totalVolume': np.float64(11107840.669999996)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 1.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 1.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 1.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.0, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.0, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.0, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'z_entry': 2.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 1.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.0707971103106013),
#  'meanPL': np.float64(-11.561205603015079),
#  'return': np.float64(-0.0006372332390728226),
#  'score': np.float64(-20.370989350264793),
#  'stdDev': np.float64(88.09783747249716),
#  'totalVolume': np.float64(3631846.069999999)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 1.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 1.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.697325446839124),
#  'meanPL': np.float64(-32.14616640703503),
#  'return': np.float64(-0.0007218819054891504),
#  'score': np.float64(-50.95212660035969),
#  'stdDev': np.float64(188.05960193324663),
#  'totalVolume': np.float64(8901491.97)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.0, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.0707971103106013),
#  'meanPL': np.float64(-11.561205603015079),
#  'return': np.float64(-0.0006372332390728226),
#  'score': np.float64(-20.370989350264793),
#  'stdDev': np.float64(88.09783747249716),
#  'totalVolume': np.float64(3631846.069999999)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.0, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.0, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.697325446839124),
#  'meanPL': np.float64(-32.14616640703503),
#  'return': np.float64(-0.0007218819054891504),
#  'score': np.float64(-50.95212660035969),
#  'stdDev': np.float64(188.05960193324663),
#  'totalVolume': np.float64(8901491.97)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.0707971103106013),
#  'meanPL': np.float64(-11.561205603015079),
#  'return': np.float64(-0.0006372332390728226),
#  'score': np.float64(-20.370989350264793),
#  'stdDev': np.float64(88.09783747249716),
#  'totalVolume': np.float64(3631846.069999999)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'z_entry': 2.5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.697325446839124),
#  'meanPL': np.float64(-32.14616640703503),
#  'return': np.float64(-0.0007218819054891504),
#  'score': np.float64(-50.95212660035969),
#  'stdDev': np.float64(188.05960193324663),
#  'totalVolume': np.float64(8901491.97)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 3, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.367517915645888),
#  'meanPL': np.float64(-14.237731859296611),
#  'return': np.float64(-0.0009741983632714071),
#  'score': np.float64(-20.909340587895443),
#  'stdDev': np.float64(66.71608728598832),
#  'totalVolume': np.float64(2914350.0)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 3, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.113428602491269),
#  'meanPL': np.float64(-25.253475402010125),
#  'return': np.float64(-0.000810052890312689),
#  'score': np.float64(-38.052648635365806),
#  'stdDev': np.float64(127.99173233355681),
#  'totalVolume': np.float64(6221551.42)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 3, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.8682882056076453),
#  'meanPL': np.float64(-27.927495954773846),
#  'return': np.float64(-0.0006961976830606886),
#  'score': np.float64(-43.291658177672055),
#  'stdDev': np.float64(153.64162222898207),
#  'totalVolume': np.float64(8011511.530000003)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.4968365003185045),
#  'meanPL': np.float64(-20.461365301507513),
#  'return': np.float64(-0.0009158582951723148),
#  'score': np.float64(-29.694708021182453),
#  'stdDev': np.float64(92.3334271967494),
#  'totalVolume': np.float64(4456253.540000003)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.369664139591623),
#  'meanPL': np.float64(-31.08147464824111),
#  'return': np.float64(-0.0007204097722551921),
#  'score': np.float64(-45.63655720026893),
#  'stdDev': np.float64(145.5508255202782),
#  'totalVolume': np.float64(8618311.16)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.2085520710456388),
#  'meanPL': np.float64(-35.62966698492471),
#  'return': np.float64(-0.0006414307286782519),
#  'score': np.float64(-53.152420217898836),
#  'stdDev': np.float64(175.22753232974122),
#  'totalVolume': np.float64(11107840.669999996)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 7, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.5569116229809796),
#  'meanPL': np.float64(-24.983556658291448),
#  'return': np.float64(-0.0008705645187778798),
#  'score': np.float64(-36.06715715735356),
#  'stdDev': np.float64(110.83600499062116),
#  'totalVolume': np.float64(5726776.019999996)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 7, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.525381494450213),
#  'meanPL': np.float64(-38.44992012562835),
#  'return': np.float64(-0.0007125508348343409),
#  'score': np.float64(-55.6602420902781),
#  'stdDev': np.float64(172.1032196464975),
#  'totalVolume': np.float64(10783914.360000007)}
#
# Testing parameters: {'lookback': 40, 'max_pairs': 7, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.3679596498561506),
#  'meanPL': np.float64(-44.0852230653272),
#  'return': np.float64(-0.0006462875557479882),
#  'score': np.float64(-64.74025336511292),
#  'stdDev': np.float64(206.55030299785713),
#  'totalVolume': np.float64(13641283.360000014)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 3, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.2758492750723205),
#  'meanPL': np.float64(-10.14977145728642),
#  'return': np.float64(-0.0007151568760492275),
#  'score': np.float64(-17.187174762829294),
#  'stdDev': np.float64(70.37403305542873),
#  'totalVolume': np.float64(2836256.0900000003)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 3, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 3, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.715456924687129),
#  'meanPL': np.float64(-31.73621997487448),
#  'return': np.float64(-0.0008096537465685874),
#  'score': np.float64(-50.17838709882275),
#  'stdDev': np.float64(184.42167123948275),
#  'totalVolume': np.float64(7824223.109999998)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 7, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.1397586222472142),
#  'meanPL': np.float64(-21.59696168341713),
#  'return': np.float64(-0.0008202206158229433),
#  'score': np.float64(-32.45111794435848),
#  'stdDev': np.float64(108.54156260941346),
#  'totalVolume': np.float64(5260373.369999997)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 7, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'lookback': 60, 'max_pairs': 7, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.991949812921457),
#  'meanPL': np.float64(-58.83550962311584),
#  'return': np.float64(-0.0009655166919365851),
#  'score': np.float64(-82.09253252140505),
#  'stdDev': np.float64(232.57022898289208),
#  'totalVolume': np.float64(12164676.58)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 3, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-1.926019557794252),
#  'meanPL': np.float64(-7.821068316582923),
#  'return': np.float64(-0.0006220436273876243),
#  'score': np.float64(-14.228810951673154),
#  'stdDev': np.float64(64.0774263509023),
#  'totalVolume': np.float64(2519344.9799999995)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 3, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.5810142908373495),
#  'meanPL': np.float64(-20.433098517587847),
#  'return': np.float64(-0.0007570177070162328),
#  'score': np.float64(-32.92542981691513),
#  'stdDev': np.float64(124.92331299327283),
#  'totalVolume': np.float64(5393752.890000003)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 3, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.7690361529235146),
#  'meanPL': np.float64(-27.291108040201063),
#  'return': np.float64(-0.000779734703436392),
#  'score': np.float64(-42.843321779462904),
#  'stdDev': np.float64(155.52213739261842),
#  'totalVolume': np.float64(6990623.5299999975)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.0707971103106013),
#  'meanPL': np.float64(-11.561205603015079),
#  'return': np.float64(-0.0006372332390728226),
#  'score': np.float64(-20.370989350264793),
#  'stdDev': np.float64(88.09783747249716),
#  'totalVolume': np.float64(3631846.069999999)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.5580263066075175),
#  'meanPL': np.float64(-25.076867412060302),
#  'return': np.float64(-0.0007096327565584586),
#  'score': np.float64(-40.54607084567978),
#  'stdDev': np.float64(154.69203433619472),
#  'totalVolume': np.float64(7066500.599999998)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.697325446839124),
#  'meanPL': np.float64(-32.14616640703503),
#  'return': np.float64(-0.0007218819054891504),
#  'score': np.float64(-50.95212660035969),
#  'stdDev': np.float64(188.05960193324663),
#  'totalVolume': np.float64(8901491.97)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 7, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.327274459849646),
#  'meanPL': np.float64(-15.996861055276282),
#  'return': np.float64(-0.0006665327794714477),
#  'score': np.float64(-26.843291678374662),
#  'stdDev': np.float64(108.46430623098377),
#  'totalVolume': np.float64(4801517.170000001)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 7, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.694793011427251),
#  'meanPL': np.float64(-30.86303442211051),
#  'return': np.float64(-0.0007013730989617503),
#  'score': np.float64(-48.93531183082457),
#  'stdDev': np.float64(180.72277408714058),
#  'totalVolume': np.float64(8799834.779999997)}
#
# Testing parameters: {'lookback': 80, 'max_pairs': 7, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.697684334801945),
#  'meanPL': np.float64(-36.3380135929646),
#  'return': np.float64(-0.0006629733296090446),
#  'score': np.float64(-57.59343533758718),
#  'stdDev': np.float64(212.55421744622575),
#  'totalVolume': np.float64(10959707.360000007)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 3, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.2758492750723205),
#  'meanPL': np.float64(-10.14977145728642),
#  'return': np.float64(-0.0007151568760492275),
#  'score': np.float64(-17.187174762829294),
#  'stdDev': np.float64(70.37403305542873),
#  'totalVolume': np.float64(2836256.0900000003)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 3, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 3, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.715456924687129),
#  'meanPL': np.float64(-31.73621997487448),
#  'return': np.float64(-0.0008096537465685874),
#  'score': np.float64(-50.17838709882275),
#  'stdDev': np.float64(184.42167123948275),
#  'totalVolume': np.float64(7824223.109999998)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 7, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.1397586222472142),
#  'meanPL': np.float64(-21.59696168341713),
#  'return': np.float64(-0.0008202206158229433),
#  'score': np.float64(-32.45111794435848),
#  'stdDev': np.float64(108.54156260941346),
#  'totalVolume': np.float64(5260373.369999997)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 7, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'z_entry': 1.5, 'max_pairs': 7, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.991949812921457),
#  'meanPL': np.float64(-58.83550962311584),
#  'return': np.float64(-0.0009655166919365851),
#  'score': np.float64(-82.09253252140505),
#  'stdDev': np.float64(232.57022898289208),
#  'totalVolume': np.float64(12164676.58)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 3, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.2758492750723205),
#  'meanPL': np.float64(-10.14977145728642),
#  'return': np.float64(-0.0007151568760492275),
#  'score': np.float64(-17.187174762829294),
#  'stdDev': np.float64(70.37403305542873),
#  'totalVolume': np.float64(2836256.0900000003)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 3, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 3, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.715456924687129),
#  'meanPL': np.float64(-31.73621997487448),
#  'return': np.float64(-0.0008096537465685874),
#  'score': np.float64(-50.17838709882275),
#  'stdDev': np.float64(184.42167123948275),
#  'totalVolume': np.float64(7824223.109999998)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 7, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.1397586222472142),
#  'meanPL': np.float64(-21.59696168341713),
#  'return': np.float64(-0.0008202206158229433),
#  'score': np.float64(-32.45111794435848),
#  'stdDev': np.float64(108.54156260941346),
#  'totalVolume': np.float64(5260373.369999997)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 7, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'z_entry': 2.0, 'max_pairs': 7, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.991949812921457),
#  'meanPL': np.float64(-58.83550962311584),
#  'return': np.float64(-0.0009655166919365851),
#  'score': np.float64(-82.09253252140505),
#  'stdDev': np.float64(232.57022898289208),
#  'totalVolume': np.float64(12164676.58)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 3, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-2.2758492750723205),
#  'meanPL': np.float64(-10.14977145728642),
#  'return': np.float64(-0.0007151568760492275),
#  'score': np.float64(-17.187174762829294),
#  'stdDev': np.float64(70.37403305542873),
#  'totalVolume': np.float64(2836256.0900000003)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 3, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-2.323867638769717),
#  'meanPL': np.float64(-21.350382236180973),
#  'return': np.float64(-0.0006955059515004684),
#  'score': np.float64(-35.847909694592076),
#  'stdDev': np.float64(144.975274584111),
#  'totalVolume': np.float64(6128918.28)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 3, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-2.715456924687129),
#  'meanPL': np.float64(-31.73621997487448),
#  'return': np.float64(-0.0008096537465685874),
#  'score': np.float64(-50.17838709882275),
#  'stdDev': np.float64(184.42167123948275),
#  'totalVolume': np.float64(7824223.109999998)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 5, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.6242248995749566),
#  'meanPL': np.float64(-20.39929346733667),
#  'return': np.float64(-0.0009710302325486052),
#  'score': np.float64(-29.281066268930466),
#  'stdDev': np.float64(88.81772801593794),
#  'totalVolume': np.float64(4193446.3300000024)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 5, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.9987342235757044),
#  'meanPL': np.float64(-43.36022208542729),
#  'return': np.float64(-0.001040810199577118),
#  'score': np.float64(-60.470955767931514),
#  'stdDev': np.float64(171.10733682504224),
#  'totalVolume': np.float64(8311917.940000003)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 5, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-4.240034992107571),
#  'meanPL': np.float64(-57.643442311557365),
#  'return': np.float64(-0.00110710170106619),
#  'score': np.float64(-79.09605246404536),
#  'stdDev': np.float64(214.52610152487998),
#  'totalVolume': np.float64(10385673.42)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 7, 'capital_per_pair': 2000}
# Statistics:
# {'annualSharpe': np.float64(-3.1397586222472142),
#  'meanPL': np.float64(-21.59696168341713),
#  'return': np.float64(-0.0008202206158229433),
#  'score': np.float64(-32.45111794435848),
#  'stdDev': np.float64(108.54156260941346),
#  'totalVolume': np.float64(5260373.369999997)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 7, 'capital_per_pair': 5000}
# Statistics:
# {'annualSharpe': np.float64(-3.838987719594455),
#  'meanPL': np.float64(-47.27302690954757),
#  'return': np.float64(-0.0009586900384683234),
#  'score': np.float64(-66.70408105292698),
#  'stdDev': np.float64(194.3105414337941),
#  'totalVolume': np.float64(9846518.610000003)}
#
# Testing parameters: {'z_entry': 2.5, 'max_pairs': 7, 'capital_per_pair': 8000}
# Statistics:
# {'annualSharpe': np.float64(-3.991949812921457),
#  'meanPL': np.float64(-58.83550962311584),
#  'return': np.float64(-0.0009655166919365851),
#  'score': np.float64(-82.09253252140505),
#  'stdDev': np.float64(232.57022898289208),
#  'totalVolume': np.float64(12164676.58)}
#
# ==================================================
# GRID SEARCH COMPLETE
# ==================================================
# Best parameters: {'lookback': 80, 'max_pairs': 3, 'capital_per_pair': 2000}
# Best statistics:
# {'annualSharpe': np.float64(-1.926019557794252),
#  'meanPL': np.float64(-7.821068316582923),
#  'return': np.float64(-0.0006220436273876243),
#  'score': np.float64(-14.228810951673154),
#  'stdDev': np.float64(64.0774263509023),
#  'totalVolume': np.float64(2519344.9799999995)}
# ({'lookback': 80, 'max_pairs': 3, 'capital_per_pair': 2000},
#  {'meanPL': np.float64(-7.821068316582923),
#   'return': np.float64(-0.0006220436273876243),
#   'stdDev': np.float64(64.0774263509023),
#   'annualSharpe': np.float64(-1.926019557794252),
#   'totalVolume': np.float64(2519344.9799999995),
#   'score': np.float64(-14.228810951673154)})

# %%
# 6. Lead-Lag Strategy
bt.set_getPos(LeadLagStrategy)
param_ranges_ll = {
    "update_interval_days": [10, 20, 30],
    "return_threshold": [0.005, 0.01, 0.02],
    "capital_allocation": [500, 1000, 2000],
}
print("Gridsearch: Lead-Lag Strategy")
bt.gridsearch(param_ranges_ll, numTestDays=NUM_TEST_DAYS)
# Out:
# Gridsearch: Lead-Lag Strategy
#
# Testing parameters: {'update_interval_days': 10, 'return_threshold': 0.005}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 10, 'return_threshold': 0.01}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 10, 'return_threshold': 0.02}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 20, 'return_threshold': 0.005}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 20, 'return_threshold': 0.01}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 20, 'return_threshold': 0.02}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 30, 'return_threshold': 0.005}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 30, 'return_threshold': 0.01}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 30, 'return_threshold': 0.02}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 10, 'capital_allocation': 500}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 10, 'capital_allocation': 1000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 10, 'capital_allocation': 2000}
# Statistics:
# {'annualSharpe': np.float64(-0.4367475595169437),
#  'meanPL': np.float64(-0.001235326633165837),
#  'return': np.float64(-0.00043002833852290095),
#  'score': np.float64(-0.005698574349073641),
#  'stdDev': np.float64(0.044632477159078046),
#  'totalVolume': np.float64(571.66)}
#
# Testing parameters: {'update_interval_days': 20, 'capital_allocation': 500}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 20, 'capital_allocation': 1000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 20, 'capital_allocation': 2000}
# Statistics:
# {'annualSharpe': np.float64(-0.4367475595169437),
#  'meanPL': np.float64(-0.001235326633165837),
#  'return': np.float64(-0.00043002833852290095),
#  'score': np.float64(-0.005698574349073641),
#  'stdDev': np.float64(0.044632477159078046),
#  'totalVolume': np.float64(571.66)}
#
# Testing parameters: {'update_interval_days': 30, 'capital_allocation': 500}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 30, 'capital_allocation': 1000}
# Statistics:
# {'annualSharpe': 0.0,
#  'meanPL': np.float64(0.0),
#  'return': 0.0,
#  'score': np.float64(0.0),
#  'stdDev': np.float64(0.0),
#  'totalVolume': np.float64(0.0)}
#
# Testing parameters: {'update_interval_days': 30, 'capital_allocation': 2000}
# Statistics:
# {'annualSharpe': np.float64(-0.4367475595169437),
#  'meanPL': np.float64(-0.001235326633165837),
#  'return': np.float64(-0.00043002833852290095),
#  'score': np.float64(-0.005698574349073641),
#  'stdDev': np.float64(0.044632477159078046),
#  'totalVolume': np.float64(571.66)}
